# %%
cd sports900
# Out:
# C:\Users\yuimaeka\Desktop\text_mining\lec6\sports900

# %%
import io
labels = []
for i in range(5):
    fname = 'tag' + str(i+1) + '.txt'
    print(fname)
    with io.open(fname, 'r', encoding = 'utf_8_sig') as f:
        line = f.readline()
        while line:
            labels.append(line.strip())
            line = f.readline()
len(labels)
# Out:
# tag1.txt
# tag2.txt
# tag3.txt
# tag4.txt
# tag5.txt
# 900

# %%
from collections import Counter
dist = Counter(labels)
for label in dist:
    print(label)
# Out:
# 柔道
# 競馬
# スノーボード
# スピードスケート
# フィギュアスケート
# 野球
# プロレス
# サッカー
# 総合格闘技
# ゴルフ
# ボクシング
# 相撲
# 総合
# バドミントン
# 水泳
# ビーチバレー
# 重量挙げ
# テニス
# 卓球
# 陸上
# レスリング
# 体操
# ラグビー
# アメリカンフットボール
# ボート
# カーリング
# バレーボール
# 高校野球
# テコンドー
# アイスホッケー
# 馬術
# 少林寺拳法
# 新体操
# アーチェリー
# フェンシング

# %%
# 「その他」に変更するラベルをリストにまとめる
replaced = ['重量挙げ', 'スノーボード', 'スピードスケート', '卓球', 'カーリング', '高校野球', 'ラグビー', 'アメリカンフットボール', 'ボート', 'テコンドー', 'アイスホッケー', '馬術', '少林寺拳法', '新体操', 'アーチェリー', 'フェンシング']

# enumerate() はリストのインデックスと対応する値のペアを返す
for i, v in enumerate(labels):
    # ラベルの値が replaced の中のいずれかと一致する場合，「その他」に置換
    if v in replaced:
        print(str(i) + ': ' + labels[i])
        labels[i] = 'その他'
        print(str(i) + ': ' + labels[i])
# Out:
# 2: スノーボード
# 2: その他
# 3: スノーボード
# 3: その他
# 4: スピードスケート
# 4: その他
# 5: スピードスケート
# 5: その他
# 29: スピードスケート
# 29: その他
# 131: スノーボード
# 131: その他
# 297: 重量挙げ
# 297: その他
# 325: 卓球
# 325: その他
# 333: 重量挙げ
# 333: その他
# 352: 重量挙げ
# 352: その他
# 389: 卓球
# 389: その他
# 468: ラグビー
# 468: その他
# 479: アメリカンフットボール
# 479: その他
# 491: ボート
# 491: その他
# 495: カーリング
# 495: その他
# 627: カーリング
# 627: その他
# 766: 高校野球
# 766: その他
# 786: テコンドー
# 786: その他
# 791: アイスホッケー
# 791: その他
# 812: 馬術
# 812: その他
# 816: 少林寺拳法
# 816: その他
# 844: 高校野球
# 844: その他
# 852: 新体操
# 852: その他
# 859: 重量挙げ
# 859: その他
# 863: アーチェリー
# 863: その他
# 875: フェンシング
# 875: その他

# %%
dist = Counter(labels)
dist.most_common
# Out:
# <bound method Counter.most_common of Counter({'サッカー': 333, '野球': 264, 'フィギュアスケート': 32, '総合': 32, 'その他': 26, '総合格闘技': 26, 'ボクシング': 24, 'ゴルフ': 22, '柔道': 19, 'プロレス': 18, '水泳': 18, '陸上': 17, '競馬': 12, 'テニス': 12, '相撲': 11, '体操': 8, 'バドミントン': 7, 'バレーボール': 7, 'ビーチバレー': 6, 'レスリング': 6})>

# %%
label_list = []
for v in dist:
    label_list.append(v)

# %%
for i, v in enumerate(labels):
    labels[i] = label_list.index(v)

# 置換後の数値ラベルの頻度分布を確認しておく
dist_id = Counter(labels)
dist_id.most_common
# Out:
# <bound method Counter.most_common of Counter({6: 333, 4: 264, 3: 32, 11: 32, 2: 26, 7: 26, 9: 24, 8: 22, 0: 19, 5: 18, 13: 18, 16: 17, 1: 12, 15: 12, 10: 11, 18: 8, 12: 7, 19: 7, 14: 6, 17: 6})>

# %%
from janome.tokenizer import Tokenizer     # for janome tokenizer
from janome.analyzer import Analyzer       # for janome anolyzer
from janome.charfilter import *            # for janome character filter
from janome.tokenfilter import *           # for janome token filter
from collections import Counter  # for Counter
import codecs                    # for file I/O
import glob                      # for file handling
from sklearn.feature_extraction.text import CountVectorizer as CV    # for CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer as TV    # for TfidfVectorizer
import re      # for regular expression

# %%
new_file_list = []
prefix = 'article_'
extension = '.txt'

# ファイル名リストの生成
for i in range(900):
    new_file_list.append(prefix + str(i+1) + extension)
new_file_list
# Out:
# ['article_1.txt',
#  'article_2.txt',
#  'article_3.txt',
#  'article_4.txt',
#  'article_5.txt',
#  'article_6.txt',
#  'article_7.txt',
#  'article_8.txt',
#  'article_9.txt',
#  'article_10.txt',
#  'article_11.txt',
#  'article_12.txt',
#  'article_13.txt',
#  'article_14.txt',
#  'article_15.txt',
#  'article_16.txt',
#  'article_17.txt',
#  'article_18.txt',
#  'article_19.txt',
#  'article_20.txt',
#  'article_21.txt',
#  'article_22.txt',
#  'article_23.txt',
#  'article_24.txt',
#  'article_25.txt',
#  'article_26.txt',
#  'article_27.txt',
#  'article_28.txt',
#  'article_29.txt',
#  'article_30.txt',
#  'article_31.txt',
#  'article_32.txt',
#  'article_33.txt',
#  'article_34.txt',
#  'article_35.txt',
#  'article_36.txt',
#  'article_37.txt',
#  'article_38.txt',
#  'article_39.txt',
#  'article_40.txt',
#  'article_41.txt',
#  'article_42.txt',
#  'article_43.txt',
#  'article_44.txt',
#  'article_45.txt',
#  'article_46.txt',
#  'article_47.txt',
#  'article_48.txt',
#  'article_49.txt',
#  'article_50.txt',
#  'article_51.txt',
#  'article_52.txt',
#  'article_53.txt',
#  'article_54.txt',
#  'article_55.txt',
#  'article_56.txt',
#  'article_57.txt',
#  'article_58.txt',
#  'article_59.txt',
#  'article_60.txt',
#  'article_61.txt',
#  'article_62.txt',
#  'article_63.txt',
#  'article_64.txt',
#  'article_65.txt',
#  'article_66.txt',
#  'article_67.txt',
#  'article_68.txt',
#  'article_69.txt',
#  'article_70.txt',
#  'article_71.txt',
#  'article_72.txt',
#  'article_73.txt',
#  'article_74.txt',
#  'article_75.txt',
#  'article_76.txt',
#  'article_77.txt',
#  'article_78.txt',
#  'article_79.txt',
#  'article_80.txt',
#  'article_81.txt',
#  'article_82.txt',
#  'article_83.txt',
#  'article_84.txt',
#  'article_85.txt',
#  'article_86.txt',
#  'article_87.txt',
#  'article_88.txt',
#  'article_89.txt',
#  'article_90.txt',
#  'article_91.txt',
#  'article_92.txt',
#  'article_93.txt',
#  'article_94.txt',
#  'article_95.txt',
#  'article_96.txt',
#  'article_97.txt',
#  'article_98.txt',
#  'article_99.txt',
#  'article_100.txt',
#  'article_101.txt',
#  'article_102.txt',
#  'article_103.txt',
#  'article_104.txt',
#  'article_105.txt',
#  'article_106.txt',
#  'article_107.txt',
#  'article_108.txt',
#  'article_109.txt',
#  'article_110.txt',
#  'article_111.txt',
#  'article_112.txt',
#  'article_113.txt',
#  'article_114.txt',
#  'article_115.txt',
#  'article_116.txt',
#  'article_117.txt',
#  'article_118.txt',
#  'article_119.txt',
#  'article_120.txt',
#  'article_121.txt',
#  'article_122.txt',
#  'article_123.txt',
#  'article_124.txt',
#  'article_125.txt',
#  'article_126.txt',
#  'article_127.txt',
#  'article_128.txt',
#  'article_129.txt',
#  'article_130.txt',
#  'article_131.txt',
#  'article_132.txt',
#  'article_133.txt',
#  'article_134.txt',
#  'article_135.txt',
#  'article_136.txt',
#  'article_137.txt',
#  'article_138.txt',
#  'article_139.txt',
#  'article_140.txt',
#  'article_141.txt',
#  'article_142.txt',
#  'article_143.txt',
#  'article_144.txt',
#  'article_145.txt',
#  'article_146.txt',
#  'article_147.txt',
#  'article_148.txt',
#  'article_149.txt',
#  'article_150.txt',
#  'article_151.txt',
#  'article_152.txt',
#  'article_153.txt',
#  'article_154.txt',
#  'article_155.txt',
#  'article_156.txt',
#  'article_157.txt',
#  'article_158.txt',
#  'article_159.txt',
#  'article_160.txt',
#  'article_161.txt',
#  'article_162.txt',
#  'article_163.txt',
#  'article_164.txt',
#  'article_165.txt',
#  'article_166.txt',
#  'article_167.txt',
#  'article_168.txt',
#  'article_169.txt',
#  'article_170.txt',
#  'article_171.txt',
#  'article_172.txt',
#  'article_173.txt',
#  'article_174.txt',
#  'article_175.txt',
#  'article_176.txt',
#  'article_177.txt',
#  'article_178.txt',
#  'article_179.txt',
#  'article_180.txt',
#  'article_181.txt',
#  'article_182.txt',
#  'article_183.txt',
#  'article_184.txt',
#  'article_185.txt',
#  'article_186.txt',
#  'article_187.txt',
#  'article_188.txt',
#  'article_189.txt',
#  'article_190.txt',
#  'article_191.txt',
#  'article_192.txt',
#  'article_193.txt',
#  'article_194.txt',
#  'article_195.txt',
#  'article_196.txt',
#  'article_197.txt',
#  'article_198.txt',
#  'article_199.txt',
#  'article_200.txt',
#  'article_201.txt',
#  'article_202.txt',
#  'article_203.txt',
#  'article_204.txt',
#  'article_205.txt',
#  'article_206.txt',
#  'article_207.txt',
#  'article_208.txt',
#  'article_209.txt',
#  'article_210.txt',
#  'article_211.txt',
#  'article_212.txt',
#  'article_213.txt',
#  'article_214.txt',
#  'article_215.txt',
#  'article_216.txt',
#  'article_217.txt',
#  'article_218.txt',
#  'article_219.txt',
#  'article_220.txt',
#  'article_221.txt',
#  'article_222.txt',
#  'article_223.txt',
#  'article_224.txt',
#  'article_225.txt',
#  'article_226.txt',
#  'article_227.txt',
#  'article_228.txt',
#  'article_229.txt',
#  'article_230.txt',
#  'article_231.txt',
#  'article_232.txt',
#  'article_233.txt',
#  'article_234.txt',
#  'article_235.txt',
#  'article_236.txt',
#  'article_237.txt',
#  'article_238.txt',
#  'article_239.txt',
#  'article_240.txt',
#  'article_241.txt',
#  'article_242.txt',
#  'article_243.txt',
#  'article_244.txt',
#  'article_245.txt',
#  'article_246.txt',
#  'article_247.txt',
#  'article_248.txt',
#  'article_249.txt',
#  'article_250.txt',
#  'article_251.txt',
#  'article_252.txt',
#  'article_253.txt',
#  'article_254.txt',
#  'article_255.txt',
#  'article_256.txt',
#  'article_257.txt',
#  'article_258.txt',
#  'article_259.txt',
#  'article_260.txt',
#  'article_261.txt',
#  'article_262.txt',
#  'article_263.txt',
#  'article_264.txt',
#  'article_265.txt',
#  'article_266.txt',
#  'article_267.txt',
#  'article_268.txt',
#  'article_269.txt',
#  'article_270.txt',
#  'article_271.txt',
#  'article_272.txt',
#  'article_273.txt',
#  'article_274.txt',
#  'article_275.txt',
#  'article_276.txt',
#  'article_277.txt',
#  'article_278.txt',
#  'article_279.txt',
#  'article_280.txt',
#  'article_281.txt',
#  'article_282.txt',
#  'article_283.txt',
#  'article_284.txt',
#  'article_285.txt',
#  'article_286.txt',
#  'article_287.txt',
#  'article_288.txt',
#  'article_289.txt',
#  'article_290.txt',
#  'article_291.txt',
#  'article_292.txt',
#  'article_293.txt',
#  'article_294.txt',
#  'article_295.txt',
#  'article_296.txt',
#  'article_297.txt',
#  'article_298.txt',
#  'article_299.txt',
#  'article_300.txt',
#  'article_301.txt',
#  'article_302.txt',
#  'article_303.txt',
#  'article_304.txt',
#  'article_305.txt',
#  'article_306.txt',
#  'article_307.txt',
#  'article_308.txt',
#  'article_309.txt',
#  'article_310.txt',
#  'article_311.txt',
#  'article_312.txt',
#  'article_313.txt',
#  'article_314.txt',
#  'article_315.txt',
#  'article_316.txt',
#  'article_317.txt',
#  'article_318.txt',
#  'article_319.txt',
#  'article_320.txt',
#  'article_321.txt',
#  'article_322.txt',
#  'article_323.txt',
#  'article_324.txt',
#  'article_325.txt',
#  'article_326.txt',
#  'article_327.txt',
#  'article_328.txt',
#  'article_329.txt',
#  'article_330.txt',
#  'article_331.txt',
#  'article_332.txt',
#  'article_333.txt',
#  'article_334.txt',
#  'article_335.txt',
#  'article_336.txt',
#  'article_337.txt',
#  'article_338.txt',
#  'article_339.txt',
#  'article_340.txt',
#  'article_341.txt',
#  'article_342.txt',
#  'article_343.txt',
#  'article_344.txt',
#  'article_345.txt',
#  'article_346.txt',
#  'article_347.txt',
#  'article_348.txt',
#  'article_349.txt',
#  'article_350.txt',
#  'article_351.txt',
#  'article_352.txt',
#  'article_353.txt',
#  'article_354.txt',
#  'article_355.txt',
#  'article_356.txt',
#  'article_357.txt',
#  'article_358.txt',
#  'article_359.txt',
#  'article_360.txt',
#  'article_361.txt',
#  'article_362.txt',
#  'article_363.txt',
#  'article_364.txt',
#  'article_365.txt',
#  'article_366.txt',
#  'article_367.txt',
#  'article_368.txt',
#  'article_369.txt',
#  'article_370.txt',
#  'article_371.txt',
#  'article_372.txt',
#  'article_373.txt',
#  'article_374.txt',
#  'article_375.txt',
#  'article_376.txt',
#  'article_377.txt',
#  'article_378.txt',
#  'article_379.txt',
#  'article_380.txt',
#  'article_381.txt',
#  'article_382.txt',
#  'article_383.txt',
#  'article_384.txt',
#  'article_385.txt',
#  'article_386.txt',
#  'article_387.txt',
#  'article_388.txt',
#  'article_389.txt',
#  'article_390.txt',
#  'article_391.txt',
#  'article_392.txt',
#  'article_393.txt',
#  'article_394.txt',
#  'article_395.txt',
#  'article_396.txt',
#  'article_397.txt',
#  'article_398.txt',
#  'article_399.txt',
#  'article_400.txt',
#  'article_401.txt',
#  'article_402.txt',
#  'article_403.txt',
#  'article_404.txt',
#  'article_405.txt',
#  'article_406.txt',
#  'article_407.txt',
#  'article_408.txt',
#  'article_409.txt',
#  'article_410.txt',
#  'article_411.txt',
#  'article_412.txt',
#  'article_413.txt',
#  'article_414.txt',
#  'article_415.txt',
#  'article_416.txt',
#  'article_417.txt',
#  'article_418.txt',
#  'article_419.txt',
#  'article_420.txt',
#  'article_421.txt',
#  'article_422.txt',
#  'article_423.txt',
#  'article_424.txt',
#  'article_425.txt',
#  'article_426.txt',
#  'article_427.txt',
#  'article_428.txt',
#  'article_429.txt',
#  'article_430.txt',
#  'article_431.txt',
#  'article_432.txt',
#  'article_433.txt',
#  'article_434.txt',
#  'article_435.txt',
#  'article_436.txt',
#  'article_437.txt',
#  'article_438.txt',
#  'article_439.txt',
#  'article_440.txt',
#  'article_441.txt',
#  'article_442.txt',
#  'article_443.txt',
#  'article_444.txt',
#  'article_445.txt',
#  'article_446.txt',
#  'article_447.txt',
#  'article_448.txt',
#  'article_449.txt',
#  'article_450.txt',
#  'article_451.txt',
#  'article_452.txt',
#  'article_453.txt',
#  'article_454.txt',
#  'article_455.txt',
#  'article_456.txt',
#  'article_457.txt',
#  'article_458.txt',
#  'article_459.txt',
#  'article_460.txt',
#  'article_461.txt',
#  'article_462.txt',
#  'article_463.txt',
#  'article_464.txt',
#  'article_465.txt',
#  'article_466.txt',
#  'article_467.txt',
#  'article_468.txt',
#  'article_469.txt',
#  'article_470.txt',
#  'article_471.txt',
#  'article_472.txt',
#  'article_473.txt',
#  'article_474.txt',
#  'article_475.txt',
#  'article_476.txt',
#  'article_477.txt',
#  'article_478.txt',
#  'article_479.txt',
#  'article_480.txt',
#  'article_481.txt',
#  'article_482.txt',
#  'article_483.txt',
#  'article_484.txt',
#  'article_485.txt',
#  'article_486.txt',
#  'article_487.txt',
#  'article_488.txt',
#  'article_489.txt',
#  'article_490.txt',
#  'article_491.txt',
#  'article_492.txt',
#  'article_493.txt',
#  'article_494.txt',
#  'article_495.txt',
#  'article_496.txt',
#  'article_497.txt',
#  'article_498.txt',
#  'article_499.txt',
#  'article_500.txt',
#  'article_501.txt',
#  'article_502.txt',
#  'article_503.txt',
#  'article_504.txt',
#  'article_505.txt',
#  'article_506.txt',
#  'article_507.txt',
#  'article_508.txt',
#  'article_509.txt',
#  'article_510.txt',
#  'article_511.txt',
#  'article_512.txt',
#  'article_513.txt',
#  'article_514.txt',
#  'article_515.txt',
#  'article_516.txt',
#  'article_517.txt',
#  'article_518.txt',
#  'article_519.txt',
#  'article_520.txt',
#  'article_521.txt',
#  'article_522.txt',
#  'article_523.txt',
#  'article_524.txt',
#  'article_525.txt',
#  'article_526.txt',
#  'article_527.txt',
#  'article_528.txt',
#  'article_529.txt',
#  'article_530.txt',
#  'article_531.txt',
#  'article_532.txt',
#  'article_533.txt',
#  'article_534.txt',
#  'article_535.txt',
#  'article_536.txt',
#  'article_537.txt',
#  'article_538.txt',
#  'article_539.txt',
#  'article_540.txt',
#  'article_541.txt',
#  'article_542.txt',
#  'article_543.txt',
#  'article_544.txt',
#  'article_545.txt',
#  'article_546.txt',
#  'article_547.txt',
#  'article_548.txt',
#  'article_549.txt',
#  'article_550.txt',
#  'article_551.txt',
#  'article_552.txt',
#  'article_553.txt',
#  'article_554.txt',
#  'article_555.txt',
#  'article_556.txt',
#  'article_557.txt',
#  'article_558.txt',
#  'article_559.txt',
#  'article_560.txt',
#  'article_561.txt',
#  'article_562.txt',
#  'article_563.txt',
#  'article_564.txt',
#  'article_565.txt',
#  'article_566.txt',
#  'article_567.txt',
#  'article_568.txt',
#  'article_569.txt',
#  'article_570.txt',
#  'article_571.txt',
#  'article_572.txt',
#  'article_573.txt',
#  'article_574.txt',
#  'article_575.txt',
#  'article_576.txt',
#  'article_577.txt',
#  'article_578.txt',
#  'article_579.txt',
#  'article_580.txt',
#  'article_581.txt',
#  'article_582.txt',
#  'article_583.txt',
#  'article_584.txt',
#  'article_585.txt',
#  'article_586.txt',
#  'article_587.txt',
#  'article_588.txt',
#  'article_589.txt',
#  'article_590.txt',
#  'article_591.txt',
#  'article_592.txt',
#  'article_593.txt',
#  'article_594.txt',
#  'article_595.txt',
#  'article_596.txt',
#  'article_597.txt',
#  'article_598.txt',
#  'article_599.txt',
#  'article_600.txt',
#  'article_601.txt',
#  'article_602.txt',
#  'article_603.txt',
#  'article_604.txt',
#  'article_605.txt',
#  'article_606.txt',
#  'article_607.txt',
#  'article_608.txt',
#  'article_609.txt',
#  'article_610.txt',
#  'article_611.txt',
#  'article_612.txt',
#  'article_613.txt',
#  'article_614.txt',
#  'article_615.txt',
#  'article_616.txt',
#  'article_617.txt',
#  'article_618.txt',
#  'article_619.txt',
#  'article_620.txt',
#  'article_621.txt',
#  'article_622.txt',
#  'article_623.txt',
#  'article_624.txt',
#  'article_625.txt',
#  'article_626.txt',
#  'article_627.txt',
#  'article_628.txt',
#  'article_629.txt',
#  'article_630.txt',
#  'article_631.txt',
#  'article_632.txt',
#  'article_633.txt',
#  'article_634.txt',
#  'article_635.txt',
#  'article_636.txt',
#  'article_637.txt',
#  'article_638.txt',
#  'article_639.txt',
#  'article_640.txt',
#  'article_641.txt',
#  'article_642.txt',
#  'article_643.txt',
#  'article_644.txt',
#  'article_645.txt',
#  'article_646.txt',
#  'article_647.txt',
#  'article_648.txt',
#  'article_649.txt',
#  'article_650.txt',
#  'article_651.txt',
#  'article_652.txt',
#  'article_653.txt',
#  'article_654.txt',
#  'article_655.txt',
#  'article_656.txt',
#  'article_657.txt',
#  'article_658.txt',
#  'article_659.txt',
#  'article_660.txt',
#  'article_661.txt',
#  'article_662.txt',
#  'article_663.txt',
#  'article_664.txt',
#  'article_665.txt',
#  'article_666.txt',
#  'article_667.txt',
#  'article_668.txt',
#  'article_669.txt',
#  'article_670.txt',
#  'article_671.txt',
#  'article_672.txt',
#  'article_673.txt',
#  'article_674.txt',
#  'article_675.txt',
#  'article_676.txt',
#  'article_677.txt',
#  'article_678.txt',
#  'article_679.txt',
#  'article_680.txt',
#  'article_681.txt',
#  'article_682.txt',
#  'article_683.txt',
#  'article_684.txt',
#  'article_685.txt',
#  'article_686.txt',
#  'article_687.txt',
#  'article_688.txt',
#  'article_689.txt',
#  'article_690.txt',
#  'article_691.txt',
#  'article_692.txt',
#  'article_693.txt',
#  'article_694.txt',
#  'article_695.txt',
#  'article_696.txt',
#  'article_697.txt',
#  'article_698.txt',
#  'article_699.txt',
#  'article_700.txt',
#  'article_701.txt',
#  'article_702.txt',
#  'article_703.txt',
#  'article_704.txt',
#  'article_705.txt',
#  'article_706.txt',
#  'article_707.txt',
#  'article_708.txt',
#  'article_709.txt',
#  'article_710.txt',
#  'article_711.txt',
#  'article_712.txt',
#  'article_713.txt',
#  'article_714.txt',
#  'article_715.txt',
#  'article_716.txt',
#  'article_717.txt',
#  'article_718.txt',
#  'article_719.txt',
#  'article_720.txt',
#  'article_721.txt',
#  'article_722.txt',
#  'article_723.txt',
#  'article_724.txt',
#  'article_725.txt',
#  'article_726.txt',
#  'article_727.txt',
#  'article_728.txt',
#  'article_729.txt',
#  'article_730.txt',
#  'article_731.txt',
#  'article_732.txt',
#  'article_733.txt',
#  'article_734.txt',
#  'article_735.txt',
#  'article_736.txt',
#  'article_737.txt',
#  'article_738.txt',
#  'article_739.txt',
#  'article_740.txt',
#  'article_741.txt',
#  'article_742.txt',
#  'article_743.txt',
#  'article_744.txt',
#  'article_745.txt',
#  'article_746.txt',
#  'article_747.txt',
#  'article_748.txt',
#  'article_749.txt',
#  'article_750.txt',
#  'article_751.txt',
#  'article_752.txt',
#  'article_753.txt',
#  'article_754.txt',
#  'article_755.txt',
#  'article_756.txt',
#  'article_757.txt',
#  'article_758.txt',
#  'article_759.txt',
#  'article_760.txt',
#  'article_761.txt',
#  'article_762.txt',
#  'article_763.txt',
#  'article_764.txt',
#  'article_765.txt',
#  'article_766.txt',
#  'article_767.txt',
#  'article_768.txt',
#  'article_769.txt',
#  'article_770.txt',
#  'article_771.txt',
#  'article_772.txt',
#  'article_773.txt',
#  'article_774.txt',
#  'article_775.txt',
#  'article_776.txt',
#  'article_777.txt',
#  'article_778.txt',
#  'article_779.txt',
#  'article_780.txt',
#  'article_781.txt',
#  'article_782.txt',
#  'article_783.txt',
#  'article_784.txt',
#  'article_785.txt',
#  'article_786.txt',
#  'article_787.txt',
#  'article_788.txt',
#  'article_789.txt',
#  'article_790.txt',
#  'article_791.txt',
#  'article_792.txt',
#  'article_793.txt',
#  'article_794.txt',
#  'article_795.txt',
#  'article_796.txt',
#  'article_797.txt',
#  'article_798.txt',
#  'article_799.txt',
#  'article_800.txt',
#  'article_801.txt',
#  'article_802.txt',
#  'article_803.txt',
#  'article_804.txt',
#  'article_805.txt',
#  'article_806.txt',
#  'article_807.txt',
#  'article_808.txt',
#  'article_809.txt',
#  'article_810.txt',
#  'article_811.txt',
#  'article_812.txt',
#  'article_813.txt',
#  'article_814.txt',
#  'article_815.txt',
#  'article_816.txt',
#  'article_817.txt',
#  'article_818.txt',
#  'article_819.txt',
#  'article_820.txt',
#  'article_821.txt',
#  'article_822.txt',
#  'article_823.txt',
#  'article_824.txt',
#  'article_825.txt',
#  'article_826.txt',
#  'article_827.txt',
#  'article_828.txt',
#  'article_829.txt',
#  'article_830.txt',
#  'article_831.txt',
#  'article_832.txt',
#  'article_833.txt',
#  'article_834.txt',
#  'article_835.txt',
#  'article_836.txt',
#  'article_837.txt',
#  'article_838.txt',
#  'article_839.txt',
#  'article_840.txt',
#  'article_841.txt',
#  'article_842.txt',
#  'article_843.txt',
#  'article_844.txt',
#  'article_845.txt',
#  'article_846.txt',
#  'article_847.txt',
#  'article_848.txt',
#  'article_849.txt',
#  'article_850.txt',
#  'article_851.txt',
#  'article_852.txt',
#  'article_853.txt',
#  'article_854.txt',
#  'article_855.txt',
#  'article_856.txt',
#  'article_857.txt',
#  'article_858.txt',
#  'article_859.txt',
#  'article_860.txt',
#  'article_861.txt',
#  'article_862.txt',
#  'article_863.txt',
#  'article_864.txt',
#  'article_865.txt',
#  'article_866.txt',
#  'article_867.txt',
#  'article_868.txt',
#  'article_869.txt',
#  'article_870.txt',
#  'article_871.txt',
#  'article_872.txt',
#  'article_873.txt',
#  'article_874.txt',
#  'article_875.txt',
#  'article_876.txt',
#  'article_877.txt',
#  'article_878.txt',
#  'article_879.txt',
#  'article_880.txt',
#  'article_881.txt',
#  'article_882.txt',
#  'article_883.txt',
#  'article_884.txt',
#  'article_885.txt',
#  'article_886.txt',
#  'article_887.txt',
#  'article_888.txt',
#  'article_889.txt',
#  'article_890.txt',
#  'article_891.txt',
#  'article_892.txt',
#  'article_893.txt',
#  'article_894.txt',
#  'article_895.txt',
#  'article_896.txt',
#  'article_897.txt',
#  'article_898.txt',
#  'article_899.txt',
#  'article_900.txt']

# %%
documents = []
for file in new_file_list:
    with codecs.open(file, 'r',  'utf8') as f:
        documents.append(f.read())
        
print(len(documents))
# Out:
# 900

# %%
stop_words =['rt', 'sports', 'watch']

def isStopWords(token, stop_list):
    if (token in stop_list) or (re.match(r'(^[0-9]+\w*$)|(^[a-zA-Z0-9_ぁ-んぁ-ン]$)|(^ー+\w*$)|(^\w*[-$!#%"\'()\[\]{}\\|~@^=+*/;:<>,.&]+\w*$)', token)):
        return True
    else:
        return False


def my_analyzer(string):
    char_filters = [UnicodeNormalizeCharFilter(), RegexReplaceCharFilter('(http(s)?://([-\w]+\.)+[-\w]+(/[-\w ./?%&=]*)?)|(@([\w]+))|(!+|(ww+))', '')]
    token_filters = [CompoundNounFilter(), POSStopFilter(['名詞,代名詞','名詞,数','記号']), LowerCaseFilter(), POSKeepFilter(['名詞']), ExtractAttributeFilter(att = 'base_form')]
    a = Analyzer(char_filters = char_filters, token_filters=token_filters)
    tokens = list(a.analyze(string))
    #return [token for token in tokens if (token not in stop_words) and (not re.match(r'(^[a-zA-Z0-9_ぁ-んぁ-ン]$)|(^ー+\w*$)|(^[-@$!#%"\'()\[\]{}\\|~^=+\*/;:<>,.&])', token))]
    return [token for token in tokens if not isStopWords(token, stop_words)]

# %%
tv = TV(analyzer=my_analyzer, min_df=0.005, max_df=0.6)
matrix_tfidf = tv.fit_transform(documents)
matrix_tfidf
# Out:
# <900x2036 sparse matrix of type '<class 'numpy.float64'>'
# 	with 34307 stored elements in Compressed Sparse Row format>

# %%
res_tfidf = matrix_tfidf.toarray()
features_tfidf = tv.get_feature_names()
tv_vocab2 = []
for i in range(900):
    print(new_file_list[i])
    ######### for the results of  TV ##########
    print('### Tfidf weight ###')
    zipped_list = [(v, i) for i, v in zip(features_tfidf, res_tfidf[i])]
    desc_list = sorted(zipped_list, reverse=True)
    for j in range(5):
        print('  ' + str(desc_list[j]))
        tv_vocab2.append(desc_list[j][1])

print(len(tv_vocab2))
tv_vocab2 = list(set(tv_vocab2))
# 重複する単語を削除した結果，延べ数より単語数が減少していることを確認
print(len(tv_vocab2))
# このあとは，CV で tv_vocab2 をつかって行列を作り直す
# Out:
# article_1.txt
# ### Tfidf weight ###
#   (0.5323721825824094, '吉田')
#   (0.35811632935155624, 'メール')
#   (0.34013444289021855, '秋山')
#   (0.2821775853537124, '対戦')
#   (0.22675629526014568, '秋山成勲')
# article_2.txt
# ### Tfidf weight ###
#   (0.5469141008493642, '騎手')
#   (0.2664451787138061, '三浦')
#   (0.20988562171731406, '注目')
#   (0.1919378951490734, '人')
#   (0.17026115169672032, '他')
# article_3.txt
# ### Tfidf weight ###
#   (0.4316710002887187, '朝青龍')
#   (0.32367132478131583, 'ニュース')
#   (0.2794263256525707, 'テレビ')
#   (0.2663347992364733, '問題')
#   (0.21583550014435934, '非難')
# article_4.txt
# ### Tfidf weight ###
#   (0.547006099454579, 'ブログ')
#   (0.2932267275259133, '状況')
#   (0.24037997149230936, '風')
#   (0.2266975446869647, '動き')
#   (0.20468624711691935, '更新')
# article_5.txt
# ### Tfidf weight ###
#   (0.37082979392543564, '動作')
#   (0.33344078530114246, '使用')
#   (0.21301843792484979, '選手')
#   (0.18655660201865684, '話題')
#   (0.18541489696271782, '日本代表選手')
# article_6.txt
# ### Tfidf weight ###
#   (0.44297473399191384, 'レース')
#   (0.26131635564466893, '吸収')
#   (0.24881149708882186, '世間')
#   (0.2311868888432952, 'オフィシャルブログ')
#   (0.2186820302874481, '判断')
# article_7.txt
# ### Tfidf weight ###
#   (0.6035018728243017, 'フリー')
#   (0.3173318038405661, '逆転')
#   (0.25885966466131394, '可能')
#   (0.23276007289968323, 'ヨナ')
#   (0.21401571911070238, '浅田')
# article_8.txt
# ### Tfidf weight ###
#   (0.41521447617273627, 'ダルビッシュ')
#   (0.29733472053271204, '本日')
#   (0.29055659425860636, '誕生')
#   (0.2699749643625639, 'オフィシャルブログ')
#   (0.2659119528918596, '女優')
# article_9.txt
# ### Tfidf weight ###
#   (0.37501906090237036, 'シリーズ')
#   (0.33477635055824057, '今年')
#   (0.3306419061309255, '馴染み')
#   (0.3220928656911187, '希望')
#   (0.27574562621396165, '予定')
# article_10.txt
# ### Tfidf weight ###
#   (0.33459614258845766, '浅田')
#   (0.285982601354886, '思い')
#   (0.25315080507222404, '舞台')
#   (0.22391504362878034, '獲得')
#   (0.1971643479151465, '運命')
# article_11.txt
# ### Tfidf weight ###
#   (0.3552872615021406, 'ヨナ')
#   (0.29874996918534397, '得点')
#   (0.19756296736192902, '要素')
#   (0.19756296736192902, '採点')
#   (0.19249714009651214, '女子フィギュアスケート')
# article_12.txt
# ### Tfidf weight ###
#   (0.2961415021762757, '安藤')
#   (0.29168469514183554, '幸せ')
#   (0.2349703709318326, 'プレッシャー')
#   (0.21449532161834797, '一つ')
#   (0.209383443931815, '舞台')
# article_13.txt
# ### Tfidf weight ###
#   (0.3798479642926396, '浅田')
#   (0.3636989472002716, '涙')
#   (0.3636989472002716, '浅田真央')
#   (0.3062931298306936, 'ママ')
#   (0.21643985115388925, '思い')
# article_14.txt
# ### Tfidf weight ###
#   (0.46236151855246327, '理想')
#   (0.31880751407048674, 'フォーム')
#   (0.2816086753810236, '一年')
#   (0.2591356051884489, '対談')
#   (0.23427303339141567, '頭')
# article_15.txt
# ### Tfidf weight ###
#   (0.3856073871605202, '答え')
#   (0.34790829915088395, '失礼')
#   (0.25332681631389026, '発言')
#   (0.24987139125064384, '問題')
#   (0.197301432771262, '苦手')
# article_16.txt
# ### Tfidf weight ###
#   (0.5909459718512936, 'レース')
#   (0.3700950421500255, '確実')
#   (0.18973218427034028, '人気')
#   (0.18339643907231082, '際')
#   (0.17695581016494805, '必要')
# article_17.txt
# ### Tfidf weight ###
#   (0.7855348999812769, 'ヨナ')
#   (0.2283957794882388, 'キム')
#   (0.18418945919492594, '演技')
#   (0.12480251706384529, '閉幕')
#   (0.12480251706384529, '恋愛')
# article_18.txt
# ### Tfidf weight ###
#   (0.35015439199777887, '違い')
#   (0.26526340554739336, '日本')
#   (0.21176212866248895, '川崎フロンターレ')
#   (0.21176212866248895, 'ペース')
#   (0.20633221242117278, '追加点')
# article_19.txt
# ### Tfidf weight ###
#   (0.4337794887515809, 'キーマン')
#   (0.3269510085501556, 'ファン')
#   (0.2219493647870524, '野手')
#   (0.19568541625899868, '持論')
#   (0.19062579584773667, 'ポイント')
# article_20.txt
# ### Tfidf weight ###
#   (0.41359934600950077, 'ブログ')
#   (0.3212777725529355, 'スポーツ選手')
#   (0.2874998892173066, '気')
#   (0.17555611045490746, '次戦')
#   (0.17555611045490746, '久々')
# article_21.txt
# ### Tfidf weight ###
#   (0.602536232620978, '騎手')
#   (0.30562835341150724, '怒り')
#   (0.2868514328520228, '命')
#   (0.2708926815868638, '骨折')
#   (0.2588072672762295, '激怒')
# article_22.txt
# ### Tfidf weight ###
#   (0.34537676683698787, '子供達')
#   (0.30450727556497936, '美人')
#   (0.2966339692334172, '柔道')
#   (0.2139808255500598, '今後')
#   (0.1981633873980809, '開催')
# article_23.txt
# ### Tfidf weight ###
#   (0.5043389870240385, '企画')
#   (0.2893887016718459, '要素')
#   (0.2647989786120191, 'mc')
#   (0.25602252656885854, '評判')
#   (0.25602252656885854, 'ネタ')
# article_24.txt
# ### Tfidf weight ###
#   (0.61746120982507, '俊輔')
#   (0.3450080119222168, 'プレー')
#   (0.2472745742034564, 'シュート')
#   (0.22760734221197526, 'プレッシャー')
#   (0.21209104738049414, '代表')
# article_25.txt
# ### Tfidf weight ###
#   (0.33784191717130063, 'エピソード')
#   (0.2997108225505015, 'お金')
#   (0.18371763603568048, '話')
#   (0.16938534076915174, '負担')
#   (0.16938534076915174, '更')
# article_26.txt
# ### Tfidf weight ###
#   (0.6372308758355437, 'ダルビッシュ')
#   (0.28589880958055464, '方')
#   (0.2040479274690878, 'バッター')
#   (0.18536799067683896, 'オープン戦')
#   (0.1835559812305212, '球')
# article_27.txt
# ### Tfidf weight ###
#   (0.4697863647779169, '高橋')
#   (0.2997537580868303, '槙原氏')
#   (0.284372119658509, '明日')
#   (0.25705955555701404, '立場')
#   (0.16071647991785853, '扱い')
# article_28.txt
# ### Tfidf weight ###
#   (0.4440106957553105, '高橋')
#   (0.26472466451644106, 'しょうが')
#   (0.25749322067067903, '復帰')
#   (0.21467595459354982, '開幕')
#   (0.21467595459354982, 'ケガ')
# article_29.txt
# ### Tfidf weight ###
#   (0.48570436709573206, '出来事')
#   (0.36206664319112253, '車')
#   (0.36206664319112253, '三浦')
#   (0.18579746269411462, '音')
#   (0.18579746269411462, 'the')
# article_30.txt
# ### Tfidf weight ###
#   (0.5195292768520622, '交際')
#   (0.2271864939521632, '話')
#   (0.20946307892162436, '花')
#   (0.20946307892162436, 'サプライズ')
#   (0.20409211395552612, '共通')
# article_31.txt
# ### Tfidf weight ###
#   (0.5047650827348998, '興毅')
#   (0.35832907842290396, '黒星')
#   (0.29410787716058034, '申し訳')
#   (0.25325447586123806, 'プロ')
#   (0.18399217100895826, '前')
# article_32.txt
# ### Tfidf weight ###
#   (0.48244373147966996, 'キム')
#   (0.4740848028973969, 'ヨナ')
#   (0.2757748825737713, '時間')
#   (0.26743756390570683, '引退')
#   (0.19453303864093152, '韓国')
# article_33.txt
# ### Tfidf weight ###
#   (0.608055498299513, '勉強')
#   (0.3712659360774771, '興毅')
#   (0.22636309089356757, 'ポイント')
#   (0.22106351340732466, '敗戦')
#   (0.16999576781993245, '経験')
# article_34.txt
# ### Tfidf weight ###
#   (0.41179737481586076, '石川遼')
#   (0.3768692443977569, 'プロゴルファー')
#   (0.24796749166632565, '出場')
#   (0.21624681839462512, '攻め')
#   (0.21624681839462512, 'news23')
# article_35.txt
# ### Tfidf weight ###
#   (0.5065854760039996, '相撲')
#   (0.4157931575178442, '申し訳')
#   (0.2599584851276937, '夏')
#   (0.2532927380019998, 'パワー')
#   (0.22970117611852206, '?」')
# article_36.txt
# ### Tfidf weight ###
#   (0.32585830761937384, '野村')
#   (0.2872984954434519, '岩隈')
#   (0.22112187455743837, 'スポーツ番組')
#   (0.21220200494808086, 'シーズン')
#   (0.21220200494808086, 'エース')
# article_37.txt
# ### Tfidf weight ###
#   (0.6320769752017174, '野村')
#   (0.4033055510379454, 'ラモス')
#   (0.22336496351789772, '本田')
#   (0.21623698367569724, '平気')
#   (0.14297220842425792, 'スポーツ番組')
# article_38.txt
# ### Tfidf weight ###
#   (0.3701614322658812, '野村')
#   (0.30073637117135615, '魔裟斗')
#   (0.24849572991797514, '次')
#   (0.23989307307816105, 'コーナー')
#   (0.23618667705043897, 'ラモス')
# article_39.txt
# ### Tfidf weight ###
#   (0.42990546489315007, '岡田監督')
#   (0.2564592921062272, '夢')
#   (0.24755148346162112, '北澤氏')
#   (0.2300161285135637, 'チャレンジ')
#   (0.2175745961800614, '胸中')
# article_40.txt
# ### Tfidf weight ###
#   (0.40872223696104265, 'ピッチャー')
#   (0.30317766099095605, '決意')
#   (0.26884013455744016, 'プロ野球')
#   (0.2637409018410605, 'プロ')
#   (0.23119804055135235, '野球')
# article_41.txt
# ### Tfidf weight ###
#   (0.3939052139873858, 'ダメ')
#   (0.3783293209345634, '秋山')
#   (0.3783293209345634, 'テレビ東京')
#   (0.3095479300791635, '試合')
#   (0.19414278894320625, '階級')
# article_42.txt
# ### Tfidf weight ###
#   (0.40474364391060563, '以下')
#   (0.32884518542751334, '通り')
#   (0.3075363636912332, '野村氏')
#   (0.2532606889583478, '監督')
#   (0.2326410852904595, '落合')
# article_43.txt
# ### Tfidf weight ###
#   (0.5895862542384498, '浅田')
#   (0.2822601673666926, '浅田真央')
#   (0.22303639510805473, '発言')
#   (0.17828141397191083, 'トリプルアクセル')
#   (0.1737099962620247, '真央')
# article_44.txt
# ### Tfidf weight ###
#   (0.42215280373787345, '決断')
#   (0.28143520249191567, '件')
#   (0.27787057252983033, '謝罪')
#   (0.27787057252983033, '行動')
#   (0.241339818413788, '足')
# article_45.txt
# ### Tfidf weight ###
#   (0.7240656234626108, '朝青龍')
#   (0.22980555671666988, '証言')
#   (0.20456863237330666, '本気')
#   (0.18406037588272672, '大変')
#   (0.15168256799453317, '力')
# article_46.txt
# ### Tfidf weight ###
#   (0.5821052902130898, '浅田')
#   (0.23016442908776175, '残念')
#   (0.22294296783131315, '浅田真央')
#   (0.21293771133545059, 'まま')
#   (0.17869799321238647, '日')
# article_47.txt
# ### Tfidf weight ###
#   (0.2777119692932099, 'リング')
#   (0.2777119692932099, 'プロレス界')
#   (0.26442252597952964, '知名度')
#   (0.26442252597952964, '目的')
#   (0.2589815509395189, '退団')
# article_48.txt
# ### Tfidf weight ###
#   (0.6303720800385542, '闘莉王')
#   (0.22734091279986787, '気持ち')
#   (0.2195433195484726, '無駄')
#   (0.2145385480240782, 'ブラジル')
#   (0.20617510277334317, '意気込み')
# article_49.txt
# ### Tfidf weight ###
#   (0.3714016348382825, '大丈夫')
#   (0.3649666465932679, 'ボクシング')
#   (0.32806605178707, '生活')
#   (0.3181679314074858, 'スタジオ')
#   (0.24002103141550518, '質問')
# article_50.txt
# ### Tfidf weight ###
#   (0.6302775409846906, '星野')
#   (0.23808502056100264, '母親')
#   (0.23072728012216343, '高校')
#   (0.2215819990953378, '入団')
#   (0.16517846828621735, '時')
# article_51.txt
# ### Tfidf weight ###
#   (0.3803240208757441, '妻')
#   (0.3265361214594351, '嫁')
#   (0.29878993527687125, '汗')
#   (0.2805139896543146, '向こう')
#   (0.22627754273399955, 'タレント')
# article_52.txt
# ### Tfidf weight ###
#   (0.34074686508315194, 'アンケート')
#   (0.3199984407300637, '先生')
#   (0.3166685015982918, '野球')
#   (0.31445407578558093, '大人')
#   (0.30042524427461315, '野球選手')
# article_53.txt
# ### Tfidf weight ###
#   (0.7060890447886745, '差')
#   (0.296700421229329, '阪神')
#   (0.296700421229329, '広島')
#   (0.22547650661561505, '巨人')
#   (0.1811822205281159, '結果')
# article_54.txt
# ### Tfidf weight ###
#   (0.6941474996053881, '真央')
#   (0.20734854450702025, '今日')
#   (0.17810373668427912, '舞')
#   (0.17810373668427912, 'トリプルアクセル')
#   (0.17810373668427912, 'テンション')
# article_55.txt
# ### Tfidf weight ###
#   (0.5758728033438352, '前田')
#   (0.47780059319898355, 'ラモス')
#   (0.25617837097929325, '岡ちゃん')
#   (0.23034912133753407, 'fw')
#   (0.19053542547489016, '電話')
# article_56.txt
# ### Tfidf weight ###
#   (0.4041461460307974, '人生')
#   (0.264573640853876, '優勝')
#   (0.2577870629662656, '重み')
#   (0.25117699454259246, 'パワー')
#   (0.24545109282781868, '間近')
# article_57.txt
# ### Tfidf weight ###
#   (0.47800287962265675, '南アフリカ')
#   (0.3210371823437524, '日本')
#   (0.277972168049216, '話')
#   (0.25858444817479975, '番組')
#   (0.2497152291540307, '拠点')
# article_58.txt
# ### Tfidf weight ###
#   (0.4404119296692877, '国民')
#   (0.36147950448597954, 'サポーター')
#   (0.30133465062886644, 'プロレス界')
#   (0.28101098908447375, '全国')
#   (0.24355737766338412, '活動')
# article_59.txt
# ### Tfidf weight ###
#   (0.37317356320450823, '懸念')
#   (0.3308399363723565, '岡田監督')
#   (0.30649115979975655, '選手')
#   (0.25577932303792916, 'チーム')
#   (0.20008136631688178, '肉体的')
# article_60.txt
# ### Tfidf weight ###
#   (0.4042293231775443, '元気')
#   (0.26502948240464225, '朝青龍')
#   (0.25823370688034997, '団体')
#   (0.25823370688034997, '参戦')
#   (0.25234693835789335, 'サンデー・ジャポン')
# article_61.txt
# ### Tfidf weight ###
#   (0.4238208273913138, '柔道家')
#   (0.387808237016045, '賛否')
#   (0.38108898429222565, 'テリー伊藤')
#   (0.2119104136956569, '政治家')
#   (0.20647669519132503, '否定的')
# article_62.txt
# ### Tfidf weight ###
#   (0.44957768824178784, '中学時代')
#   (0.37433616554200166, 'vtr')
#   (0.24104633071155168, '相方')
#   (0.24104633071155168, '印象的')
#   (0.24104633071155168, '中学校')
# article_63.txt
# ### Tfidf weight ###
#   (0.4494134027143884, 'アッコ')
#   (0.40805986991528337, 'ネタ')
#   (0.2306201675722582, 'おまかせ')
#   (0.219584223922645, '答え')
#   (0.219584223922645, '石川')
# article_64.txt
# ### Tfidf weight ###
#   (0.3612230009993052, '監督')
#   (0.324249367860398, 'ブラジル')
#   (0.318048233135821, '批判')
#   (0.2849848616835442, '勝手')
#   (0.17027280515722906, '騒ぎ')
# article_65.txt
# ### Tfidf weight ###
#   (0.468893632384121, '病院')
#   (0.29738409541396865, '東京')
#   (0.2143204846520927, 'ブログ')
#   (0.18194066813378273, '検査')
#   (0.18194066813378273, '今年3月')
# article_66.txt
# ### Tfidf weight ###
#   (0.4716852716279842, '前田')
#   (0.3329820385674187, '自然')
#   (0.3328492951985101, 'エース')
#   (0.3093951945058978, '真っ直ぐ')
#   (0.2857886855299679, '中')
# article_67.txt
# ### Tfidf weight ###
#   (0.5394378583698539, '俊輔')
#   (0.2722789024051096, 'w杯')
#   (0.26971892918492696, 'ミーティング')
#   (0.2641689710031221, '静か')
#   (0.23150774908346813, '初戦')
# article_68.txt
# ### Tfidf weight ###
#   (0.6673074780239873, '柔道')
#   (0.4643784070524534, '無理')
#   (0.2650732772760075, '絶対')
#   (0.1792518292037499, 'プロレスラー')
#   (0.17371226006428614, '表明')
# article_69.txt
# ### Tfidf weight ###
#   (0.366464007689845, '人材')
#   (0.332743203481154, '理想')
#   (0.26858249299464154, '素直')
#   (0.2500512568151729, '目標')
#   (0.23321427910352957, '前向き')
# article_70.txt
# ### Tfidf weight ###
#   (0.5279428157125666, '貢献')
#   (0.3446260861742317, '獲得')
#   (0.3114400935411168, '功績')
#   (0.3034542764698725, '露呈')
#   (0.2713847852175492, '発展')
# article_71.txt
# ### Tfidf weight ###
#   (0.44600934841570367, '音')
#   (0.3886466570458915, '女優')
#   (0.22300467420785183, '豪快')
#   (0.22300467420785183, '激突')
#   (0.22300467420785183, '公言')
# article_72.txt
# ### Tfidf weight ###
#   (0.41577217317669923, '防衛')
#   (0.3636672634141494, '今')
#   (0.3199543581290789, 'ニュース')
#   (0.3124758674259389, '動き')
#   (0.3057107496858541, '成功')
# article_73.txt
# ### Tfidf weight ###
#   (0.5144522933340314, '女性')
#   (0.4008154299153372, 'フィギュアスケート')
#   (0.31290374916075336, 'プロ野球')
#   (0.22287960835895101, '男性')
#   (0.2171646223369918, '同紙')
# article_74.txt
# ### Tfidf weight ###
#   (0.48518738883853185, '暴言')
#   (0.37338149916154856, 'ファン')
#   (0.25346851483845534, '指揮')
#   (0.25346851483845534, '同紙')
#   (0.24769037497975677, 'サイン')
# article_75.txt
# ### Tfidf weight ###
#   (0.33268581310081746, '澤登氏')
#   (0.3251018133352981, 'キーマン')
#   (0.3184122514484393, '闘莉王')
#   (0.2933180812774944, '韓国戦')
#   (0.2527879858809996, '日本代表')
# article_76.txt
# ### Tfidf weight ###
#   (0.685851704389654, 'プロレス')
#   (0.5537395950847624, '坂田')
#   (0.19916346362884324, 'プロレスラー')
#   (0.13314815307480551, '一人')
#   (0.1107479190169525, '選択肢')
# article_77.txt
# ### Tfidf weight ###
#   (0.671245646958708, '岡田監督')
#   (0.23961677930101744, '自信')
#   (0.2319701746329859, '趣味')
#   (0.2122593762520838, '冗談')
#   (0.17174062486740463, '日本代表')
# article_78.txt
# ### Tfidf weight ###
#   (0.5076131432459193, '岡田監督')
#   (0.33451705752943756, '騒動')
#   (0.23826391586253298, '意味')
#   (0.20465874903071266, '近く')
#   (0.19941097468924626, '完敗')
# article_79.txt
# ### Tfidf weight ###
#   (0.3071308912078687, '日本')
#   (0.2828017645478301, 'w杯')
#   (0.23780879598071814, '体')
#   (0.22202555330187373, '最後')
#   (0.21229587093425512, '長友')
# article_80.txt
# ### Tfidf weight ###
#   (0.5444896040929252, '大事')
#   (0.32415794440743256, '魔裟斗')
#   (0.31781898869374925, '意味')
#   (0.2545810718899325, 'ラモス')
#   (0.16479816120838417, '野球')
# article_81.txt
# ### Tfidf weight ###
#   (0.4042748992691518, '結婚')
#   (0.40082705910023503, '度')
#   (0.38164614841043426, '手術')
#   (0.2324266609097349, '今年')
#   (0.20041352955011751, '先月末')
# article_82.txt
# ### Tfidf weight ###
#   (0.3413155454309347, '岡田監督')
#   (0.27920551408357075, 'ダメ')
#   (0.274467695868466, '目標')
#   (0.2570403015876064, '批判')
#   (0.23327375964755329, '本気')
# article_83.txt
# ### Tfidf weight ###
#   (0.667076306695382, '俊輔')
#   (0.3446175942885032, '本田')
#   (0.2136231021438046, '本田圭佑')
#   (0.21324613220530075, 'チーム')
#   (0.18316325548457307, '議論')
# article_84.txt
# ### Tfidf weight ###
#   (0.38926763651938623, '中村')
#   (0.30266827575018035, '本田圭佑')
#   (0.29295936256817845, '本田')
#   (0.2836104996217184, '可能')
#   (0.25951175767959084, 'スタメン')
# article_85.txt
# ### Tfidf weight ###
#   (0.4970825570486304, '松井')
#   (0.4612512668441068, '矢部')
#   (0.27649699342221856, '松井大輔')
#   (0.2641615523110834, '裏')
#   (0.23876880165474756, '起用')
# article_86.txt
# ### Tfidf weight ###
#   (0.5560596607720041, '予想')
#   (0.3501248319431486, 'カメルーン戦')
#   (0.3072878185581674, '期待')
#   (0.2062978398608117, 'ボール')
#   (0.18386076643279883, '日本代表メンバー')
# article_87.txt
# ### Tfidf weight ###
#   (0.3745089632565276, '視聴者')
#   (0.35019745358771553, '番組')
#   (0.2682359116642239, '野村氏')
#   (0.2555613568380634, '放送')
#   (0.24565378760086148, '明日')
# article_88.txt
# ### Tfidf weight ###
#   (0.35465352885234974, '勝利')
#   (0.3438125439266432, 'セルジオ越後氏')
#   (0.2943399724853997, 'レベル')
#   (0.20277987150369947, '日本代表')
#   (0.20015385481010972, '先制')
# article_89.txt
# ### Tfidf weight ###
#   (0.5651023724917121, 'カメルーン')
#   (0.33376915765984, '勝利')
#   (0.300226067249414, '皆さん')
#   (0.18836745749723738, '横浜fc')
#   (0.18836745749723738, '中西哲生氏')
# article_90.txt
# ### Tfidf weight ###
#   (0.3258515367302673, 'w杯')
#   (0.24773841915051323, '高橋尚子')
#   (0.24209090417163356, '先月')
#   (0.22862236931085222, '基本')
#   (0.22615255784687896, 'ところ')
# article_91.txt
# ### Tfidf weight ###
#   (0.5569898783675796, 'みの')
#   (0.4655177996265227, '上機嫌')
#   (0.20843461980945865, '日本')
#   (0.1678869430340362, '番組')
#   (0.1663952051234656, 'ラモスさん')
# article_92.txt
# ### Tfidf weight ###
#   (0.3102877492599877, '日本戦')
#   (0.2537429766729023, 'ユニフォーム')
#   (0.23356127378448138, 'ゲーム')
#   (0.20839603480390753, '日本')
#   (0.20258852497084037, 'ゴール')
# article_93.txt
# ### Tfidf weight ###
#   (0.5497174822497582, '岡田監督')
#   (0.17312741293707995, '相手')
#   (0.16622573765250845, '平気')
#   (0.16622573765250845, '勝ち点3')
#   (0.16196344657003314, 'カメルーン')
# article_94.txt
# ### Tfidf weight ###
#   (0.5225288110341388, '全日本プロレス')
#   (0.3886364369977415, '告白')
#   (0.3483525406894259, 'プロレス界')
#   (0.3483525406894259, 'バッシング')
#   (0.23989036232320696, '当時')
# article_95.txt
# ### Tfidf weight ###
#   (0.6634931835661599, 'オランダ')
#   (0.2619637783108695, '差')
#   (0.21397681912379338, '力')
#   (0.17023848004186362, 'データ')
#   (0.17023848004186362, 'スポーツジャーナリスト')
# article_96.txt
# ### Tfidf weight ###
#   (0.4240230710761627, '姿勢')
#   (0.3246901867973844, '勝ち')
#   (0.28723552182484263, '攻撃')
#   (0.25468493206158066, '後半')
#   (0.19153881658864116, '攻め')
# article_97.txt
# ### Tfidf weight ###
#   (0.3847043043659132, '岡崎')
#   (0.3442262351818001, '現役')
#   (0.33161492467291004, 'シュート')
#   (0.2824606276522617, 'オランダ')
#   (0.25646953624394214, '決定的')
# article_98.txt
# ### Tfidf weight ###
#   (0.4499672313790606, '日本サッカー')
#   (0.38654866948166006, '快勝')
#   (0.35148736790975654, '相手')
#   (0.29915574240973386, '大事')
#   (0.2249836156895303, '次戦')
# article_99.txt
# ### Tfidf weight ###
#   (0.8270347724479328, 'みの')
#   (0.24759182894971726, '日本')
#   (0.1925865715973115, '歓喜')
#   (0.1748653931519993, 'ゲスト解説')
#   (0.16752885815337798, '朝ズバッ')
# article_100.txt
# ### Tfidf weight ###
#   (0.3922723434969131, '誇り')
#   (0.312726248082008, '試合')
#   (0.29659240316348023, '日本人')
#   (0.2771964480077967, '部分')
#   (0.19613617174845654, '一人一人')
# article_101.txt
# ### Tfidf weight ###
#   (0.566849977849608, '守り')
#   (0.23749576701817462, '力')
#   (0.20908385846438846, 'サッカー')
#   (0.19011346526853826, '最後')
#   (0.18894999261653597, '日本サッカー界')
# article_102.txt
# ### Tfidf weight ###
#   (0.34819577023266024, '日本代表')
#   (0.3238742496863257, '本田')
#   (0.23515412759706072, '是非')
#   (0.23515412759706072, 'あと一歩')
#   (0.22912440346878227, '横浜fc')
# article_103.txt
# ### Tfidf weight ###
#   (0.43383175540872637, '岡田監督')
#   (0.34982334690547556, 'お前ら')
#   (0.3330831338338746, 'カメルーン戦')
#   (0.2236029783818893, 'チーム')
#   (0.17266265741794226, '結果')
# article_104.txt
# ### Tfidf weight ###
#   (0.534937374667559, '岡崎')
#   (0.4229040330771372, 'ホテル')
#   (0.23686767045833493, '感じ')
#   (0.20819493348678678, '自信')
#   (0.19569998161600233, '点')
# article_105.txt
# ### Tfidf weight ###
#   (0.49424485399738005, '長谷部')
#   (0.41798925570508666, 'キャプテン')
#   (0.36039973457917, '長友')
#   (0.2328964386853099, '阿部')
#   (0.20185561446596564, '松井')
# article_106.txt
# ### Tfidf weight ###
#   (0.4695751952487989, '松井')
#   (0.3202159512421329, '岡田監督')
#   (0.26671994415938005, '姿')
#   (0.20605588668896044, 'プレー')
#   (0.18869066669527532, '運動量')
# article_107.txt
# ### Tfidf weight ###
#   (0.6472108911235368, '岡田監督')
#   (0.41553957043569983, '高校時代')
#   (0.30510073983466174, 'アッコ')
#   (0.21302968527085636, '写真')
#   (0.1681761038570984, '紹介')
# article_108.txt
# ### Tfidf weight ###
#   (0.24205882516965163, '大相撲')
#   (0.24205882516965163, '体質')
#   (0.23585205366407494, 'nhk')
#   (0.23047550363023397, '維持')
#   (0.23047550363023397, '程度')
# article_109.txt
# ### Tfidf weight ###
#   (0.390728573722536, '松井')
#   (0.3753653874878234, 'vtr')
#   (0.2948943366091168, 'エール')
#   (0.2167006350800517, '顔')
#   (0.1913489826908651, '登場')
# article_110.txt
# ### Tfidf weight ###
#   (0.5951090360622483, '川島')
#   (0.2502043071201488, '?”')
#   (0.19116047531999283, '世界')
#   (0.17284651990996727, '感じ')
#   (0.16545978396645472, '真面目')
# article_111.txt
# ### Tfidf weight ###
#   (0.50428371055072, '責任')
#   (0.30129951985279557, '弟')
#   (0.30129951985279557, '大相撲')
#   (0.28097822772062003, '影')
#   (0.26254842320295696, '一切')
# article_112.txt
# ### Tfidf weight ###
#   (0.4261792450912251, 'テリー伊藤')
#   (0.3349254629835204, '部分')
#   (0.2649703225136867, '開催')
#   (0.23698354940255004, '体質')
#   (0.230906916002833, '相撲')
# article_113.txt
# ### Tfidf weight ###
#   (0.42680390775025917, '活動')
#   (0.36141478037722546, '記事')
#   (0.3165403026128326, '運営')
#   (0.2597743970836423, '関係者')
#   (0.21818425350503037, '内容')
# article_114.txt
# ### Tfidf weight ###
#   (0.5497648123155332, 'スペイン')
#   (0.3930171039143861, '矢部')
#   (0.2971555075618944, '予想')
#   (0.20168189377696297, '優勝')
#   (0.1914697615721071, '矢部浩之')
# article_115.txt
# ### Tfidf weight ###
#   (0.38602468204835066, '幅')
#   (0.23303199546968725, '野球')
#   (0.21505527390405998, '期待')
#   (0.1963963150305746, '出演')
#   (0.19301234102417533, '近況')
# article_116.txt
# ### Tfidf weight ###
#   (0.3811314804169068, '自分')
#   (0.31756482296407834, 'pk')
#   (0.23747438686220299, '頭')
#   (0.21230384774786115, '目')
#   (0.19703507077410617, '責任')
# article_117.txt
# ### Tfidf weight ###
#   (0.5964864337240734, '川島')
#   (0.5251338328817816, '魔裟斗')
#   (0.20603819118731342, 'ストレート')
#   (0.1326741964678658, '気合い')
#   (0.1326741964678658, 'ラモスさん')
# article_118.txt
# ### Tfidf weight ###
#   (0.5929813628171136, '長谷部')
#   (0.33135545662873134, '理想')
#   (0.23213253289654762, '内容')
#   (0.18246781201789608, '日記')
#   (0.1783082242354763, '素顔')
# article_119.txt
# ### Tfidf weight ###
#   (0.4894103721327471, '坂田')
#   (0.38001823454406336, '去年')
#   (0.28431049069356357, '左')
#   (0.25575800617379013, '緊張')
#   (0.1632367511081258, '活躍')
# article_120.txt
# ### Tfidf weight ###
#   (0.6090451828069195, '魔裟斗')
#   (0.6034258737449157, '興毅')
#   (0.1949841990627233, '質問')
#   (0.1478074842759524, '結婚')
#   (0.14567613945633823, '?」')
# article_121.txt
# ### Tfidf weight ###
#   (0.5276573910218632, '入籍')
#   (0.3815778531438219, '誕生日')
#   (0.25887048364291393, 'ブログ上')
#   (0.23675235373449716, '大切')
#   (0.22866516871935474, 'モデル')
# article_122.txt
# ### Tfidf weight ###
#   (0.42460627819987345, '事件')
#   (0.3431931622929784, '子供')
#   (0.28307085213324895, '世代')
#   (0.2758124673259668, '親')
#   (0.26812153271239675, '事')
# article_123.txt
# ### Tfidf weight ###
#   (0.6072075034480825, '坂田')
#   (0.3944251611513408, 'キャスター')
#   (0.363990434618253, '大人')
#   (0.1972125805756704, '運命')
#   (0.19271686688441628, 'チャンピオン')
# article_124.txt
# ### Tfidf weight ###
#   (0.5431693742930408, 'ハプニング')
#   (0.42321126345196436, '練習')
#   (0.3155404137881313, '胸')
#   (0.2407467716006173, 'エピソード')
#   (0.18105645809768026, '顛末')
# article_125.txt
# ### Tfidf weight ###
#   (0.4715256474341553, '秋山')
#   (0.4281374191147169, '相談')
#   (0.24196724701375022, '公式ブログ上')
#   (0.24196724701375022, 'ファイトマネー')
#   (0.23576282371707766, '秋山成勲')
# article_126.txt
# ### Tfidf weight ###
#   (0.6339369622572214, 'フリーキック')
#   (0.3803621773543328, '遠藤')
#   (0.27106183961478303, '一つ')
#   (0.21697789038465856, 'イメージ')
#   (0.15821133098374301, 'ボール')
# article_127.txt
# ### Tfidf weight ###
#   (0.5615682667823207, 'ラモス')
#   (0.3421405903431787, 'チーム')
#   (0.2364509003792701, 'ブログ')
#   (0.20072759197831, '今年6月')
#   (0.19558061872748633, '仲間')
# article_128.txt
# ### Tfidf weight ###
#   (0.4010397067881862, '楽天')
#   (0.35336587700108624, '桑田氏')
#   (0.19145612044409066, '人物')
#   (0.19145612044409066, 'オーナー')
#   (0.1870916326439595, '節')
# article_129.txt
# ### Tfidf weight ###
#   (0.6279045484637557, 'リツイート')
#   (0.3139522742318778, '不可解')
#   (0.2990984238854921, 'ダルビッシュ')
#   (0.22995417192936693, '時間')
#   (0.21454729542851175, 'ツイート')
# article_130.txt
# ### Tfidf weight ###
#   (0.39467399939138614, '成績')
#   (0.3445442549550645, 'シーズン')
#   (0.3079208713495595, '理由')
#   (0.27852734811071633, '変化')
#   (0.18100239925609585, 'ショット')
# article_131.txt
# ### Tfidf weight ###
#   (0.5777514089175587, 'ダル')
#   (0.26157187238821544, '事')
#   (0.25269068593014044, '公開')
#   (0.17968745700336794, 'ツイート')
#   (0.16265162325566446, '二人')
# article_132.txt
# ### Tfidf weight ###
#   (0.4842573912477405, 'ブログ')
#   (0.33987846576764164, '報告')
#   (0.3322726351901217, '子供')
#   (0.3222475974758015, '人生')
#   (0.20554757856058312, 'ママ')
# article_133.txt
# ### Tfidf weight ###
#   (0.6380340761860064, 'ネタ')
#   (0.39027827634902795, '長友')
#   (0.21238369514332406, 'ブログ')
#   (0.1802964912935153, '無事')
#   (0.1802964912935153, '奮闘')
# article_134.txt
# ### Tfidf weight ###
#   (0.5695814986345712, 'ダル')
#   (0.26424734996796934, 'ストレート')
#   (0.2099686302388408, 'テレビ朝日')
#   (0.19733689231647067, '今年')
#   (0.17015682686658123, '通常')
# article_135.txt
# ### Tfidf weight ###
#   (0.4041253672241188, '甲子園')
#   (0.363553305913275, '決勝')
#   (0.2845330950608027, '今日')
#   (0.24440204083012698, '沖縄')
#   (0.22791822674427845, '上機嫌')
# article_136.txt
# ### Tfidf weight ###
#   (0.5248248593139283, '球場')
#   (0.3033231848860365, '秘密')
#   (0.2989039875018466, '目')
#   (0.2679310760825558, '広島')
#   (0.2651027410129048, '横浜')
# article_137.txt
# ### Tfidf weight ###
#   (0.37675233322948126, '来年')
#   (0.3140663061070434, 'ハプニング')
#   (0.30601314878778146, '東北電力ビッグスワンスタジアム')
#   (0.28737969586628737, 'おかけ')
#   (0.2778548323937435, '水')
# article_138.txt
# ### Tfidf weight ###
#   (0.48818094795990247, '前田')
#   (0.2839746028044082, '時間')
#   (0.28357955543592794, '感じ')
#   (0.2714605535834464, 'ご飯')
#   (0.2035438955719901, 'ロンドン')
# article_139.txt
# ### Tfidf weight ###
#   (0.49172175058657536, '加藤')
#   (0.33317749037759525, '日本サッカー協会')
#   (0.2947765458307494, '監督')
#   (0.25059982470150427, '怒り')
#   (0.19530911922362632, '発表')
# article_140.txt
# ### Tfidf weight ###
#   (0.571805560261418, '岡崎')
#   (0.29058010143631724, 'キレ')
#   (0.24751588899202615, '選手')
#   (0.16158155193454152, '運')
#   (0.16158155193454152, '思い出')
# article_141.txt
# ### Tfidf weight ###
#   (0.43272450111242106, '闘莉王')
#   (0.43272450111242106, 'お父さん')
#   (0.24488350167504475, '魔裟斗')
#   (0.2171288841033625, '人')
#   (0.21302953313469816, '現状')
# article_142.txt
# ### Tfidf weight ###
#   (0.41148865034655935, 'ラモス')
#   (0.3097376984815198, '間違い')
#   (0.30386274008591746, '現状')
#   (0.22062444798671257, '露骨')
#   (0.22062444798671257, '代表監督')
# article_143.txt
# ### Tfidf weight ###
#   (0.4107983517428201, 'レフェリー')
#   (0.4107983517428201, 'ショック')
#   (0.40026483162700455, '解説者')
#   (0.3830918578285232, '引退後')
#   (0.3189774334013794, '明らか')
# article_144.txt
# ### Tfidf weight ###
#   (0.48009825882578927, '北島')
#   (0.43930370410465125, 'フォーム')
#   (0.43169222933789175, '指導')
#   (0.298478532729451, '北島康介')
#   (0.17135503706978536, '現在')
# article_145.txt
# ### Tfidf weight ###
#   (0.5256388543350489, '手術')
#   (0.41059805042490843, '告白')
#   (0.3251528090546085, 'ブログ')
#   (0.2689504987034334, '女子フィギュアスケート')
#   (0.26281942716752443, '一週間')
# article_146.txt
# ### Tfidf weight ###
#   (0.3616553043567885, '仲間')
#   (0.34613883482196683, '衝撃')
#   (0.2760637433479289, '告白')
#   (0.24408528411044744, '心')
#   (0.20750336172916548, '?')
# article_147.txt
# ### Tfidf weight ###
#   (0.5213127330198922, 'ザッケローニ')
#   (0.34646757358056224, '評価')
#   (0.2651466735779584, '取材')
#   (0.21447202755442352, '勝利')
#   (0.19765279429992538, '監督')
# article_148.txt
# ### Tfidf weight ###
#   (0.6819765844021863, 'アッコ')
#   (0.3096116789526221, 'イチロー')
#   (0.17498093428595593, '邪魔')
#   (0.17498093428595593, 'ご飯')
#   (0.17498093428595593, 'おまかせ')
# article_149.txt
# ### Tfidf weight ###
#   (0.27128055623599495, '同誌')
#   (0.2237364620322276, '負担')
#   (0.2237364620322276, '御飯')
#   (0.2237364620322276, 'レフェリー')
#   (0.2179995049255124, '解説者')
# article_150.txt
# ### Tfidf weight ###
#   (0.36600751883065974, '意見')
#   (0.33971887960287644, '事')
#   (0.26899512255350266, 'コメント欄')
#   (0.26899512255350266, '——?')
#   (0.2620976617373807, 'アンケート')
# article_151.txt
# ### Tfidf weight ###
#   (0.4016461955117942, '週刊文春')
#   (0.3499891913820775, 'ドラフト')
#   (0.31794879747031907, '現役')
#   (0.30902753271346695, '両者')
#   (0.24670559980550794, '巨人')
# article_152.txt
# ### Tfidf weight ###
#   (0.3520663576198174, '時')
#   (0.33861821402159137, '北島')
#   (0.3157799444758244, '北島康介')
#   (0.2582343108163183, '試合前')
#   (0.16930910701079568, '絶対的')
# article_153.txt
# ### Tfidf weight ###
#   (0.5156399073939559, 'スピード')
#   (0.31905595927386626, '目玉')
#   (0.2919940379559511, 'ドラフト')
#   (0.2579346738957937, '優勝')
#   (0.24922768508051538, '斎藤')
# article_154.txt
# ### Tfidf weight ###
#   (0.3708198952843772, '熱愛報道')
#   (0.3458097677402703, '皆様')
#   (0.28530970441479575, 'マスコミ')
#   (0.2341576274034643, '事')
#   (0.1854099476421886, '記述')
# article_155.txt
# ### Tfidf weight ###
#   (0.5111809875959576, '金メダル')
#   (0.47263858850664653, '夫')
#   (0.2534107018472467, '柔道家')
#   (0.23187807482061815, '......」')
#   (0.22786050315215467, '?』')
# article_156.txt
# ### Tfidf weight ###
#   (0.4620067051593553, '興毅')
#   (0.3080044701062369, '進化')
#   (0.3080044701062369, '宣言')
#   (0.2664623259054542, '現役')
#   (0.2613686845686613, 'つもり')
# article_157.txt
# ### Tfidf weight ###
#   (0.6302774445364211, '槙野')
#   (0.5768181120377588, 'パフォーマンス')
#   (0.16650754642415744, '話題')
#   (0.16548853929416346, '動作')
#   (0.15756936113410527, '沢山')
# article_158.txt
# ### Tfidf weight ###
#   (0.6018592150540529, '阪神')
#   (0.2744285553539811, '巨人')
#   (0.2434224603777772, '断言')
#   (0.229271149933597, '優勝')
#   (0.22520344175651935, '予想')
# article_159.txt
# ### Tfidf weight ###
#   (0.6903380831348281, '香川')
#   (0.22835417113293022, '子')
#   (0.1941581327369292, '他')
#   (0.18222684286870766, '練習')
#   (0.1559190389736665, '急')
# article_160.txt
# ### Tfidf weight ###
#   (0.3370898383592317, '桑田氏')
#   (0.27462745025768004, '方')
#   (0.2649119390019547, 'ケガ')
#   (0.18744400925672244, '注意')
#   (0.18744400925672244, '一塁')
# article_161.txt
# ### Tfidf weight ###
#   (0.5385195380237155, 'ヨナ')
#   (0.2917736777766112, '拠点')
#   (0.25724720430678083, '裏')
#   (0.1497260519058877, '手紙')
#   (0.1497260519058877, '恋人')
# article_162.txt
# ### Tfidf weight ###
#   (0.7072506884447878, 'キャッチャー')
#   (0.27213642440986335, 'ファン')
#   (0.2036614920814785, '紹介')
#   (0.18960036029540325, '野村克也')
#   (0.18960036029540325, '立役者')
# article_163.txt
# ### Tfidf weight ###
#   (0.535367920780522, 'アナウンサー')
#   (0.39005545092737937, 'wbc')
#   (0.25849183895300376, '?」')
#   (0.19502772546368968, '秋')
#   (0.19502772546368968, '王者')
# article_164.txt
# ### Tfidf weight ###
#   (0.49141839226550205, '魔裟斗')
#   (0.3786878338763728, '人達')
#   (0.37212660330832326, '視聴者')
#   (0.20692674337119407, '坂田')
#   (0.20162081406414256, '防衛')
# article_165.txt
# ### Tfidf weight ###
#   (0.6152478511276583, '宮崎')
#   (0.40081499155407535, '付き合い')
#   (0.24291530896032706, '女性')
#   (0.1925949272004103, 'スポーツ選手')
#   (0.16832687262331347, '朝')
# article_166.txt
# ### Tfidf weight ###
#   (0.6998185774583489, '石井')
#   (0.2394117556038442, '石井慧')
#   (0.1197058778019221, '物')
#   (0.1197058778019221, '柔道家')
#   (0.1197058778019221, '名古屋')
# article_167.txt
# ### Tfidf weight ###
#   (0.6533298117334523, '浅尾')
#   (0.2613319246933809, 'スポーツライター')
#   (0.23040771715861547, '不満')
#   (0.20636081901541728, 'ミス')
#   (0.17018181547070438, '日')
# article_168.txt
# ### Tfidf weight ###
#   (0.40370109880422794, '落合監督')
#   (0.40370109880422794, 'ヤツ')
#   (0.26021393243594515, 'ヤクルト')
#   (0.23283457265162144, '球場')
#   (0.23055856780561967, '中日')
# article_169.txt
# ### Tfidf weight ###
#   (0.3508731513130339, '監督')
#   (0.322306280759477, '現時点')
#   (0.3133188823474447, 'コーナー')
#   (0.2703385529079692, '一言')
#   (0.2645412324528579, 'オファー')
# article_170.txt
# ### Tfidf weight ###
#   (0.46858703276294594, '香川')
#   (0.3425896073279476, '壁')
#   (0.30837408957395096, '自分')
#   (0.2368716330160476, '刺激')
#   (0.22839307155196506, 'ドルトムント')
# article_171.txt
# ### Tfidf weight ###
#   (0.4772316938565812, '吉田')
#   (0.3126420468068232, 'キレ')
#   (0.2909710555056279, '柔道')
#   (0.23379314396290282, '金メダル')
#   (0.1738494372922823, '負けず嫌い')
# article_172.txt
# ### Tfidf weight ###
#   (0.45214388855463167, '石川遼')
#   (0.3230638910810998, '瞬間')
#   (0.3157106770078293, 'going')
#   (0.2313457677444934, '真っ白')
#   (0.22607194427731583, '証明')
# article_173.txt
# ### Tfidf weight ###
#   (0.34239916579919466, '名前')
#   (0.26033778399320145, '今月2日')
#   (0.26033778399320145, 'メーカー')
#   (0.2536623110440889, '文字')
#   (0.24787975335234716, 'フジ')
# article_174.txt
# ### Tfidf weight ###
#   (0.4261708766132567, '石川遼')
#   (0.3959829840365725, '酒')
#   (0.22379476362925943, 'メーカー')
#   (0.21805631157729305, 'アプローチ')
#   (0.21308543830662835, '石川')
# article_175.txt
# ### Tfidf weight ###
#   (0.39247461098021214, '苦悩')
#   (0.3190142683242154, '斎藤')
#   (0.2616497406534748, '三振')
#   (0.20486114985630718, '斎藤佑樹')
#   (0.13930744267704032, '手応え')
# article_176.txt
# ### Tfidf weight ###
#   (0.5764390878969761, 'プロ野球界')
#   (0.29478069050918965, '人')
#   (0.28921528858593776, '関係')
#   (0.26029505655924196, '間')
#   (0.22273965528592982, '監督')
# article_177.txt
# ### Tfidf weight ###
#   (0.4632141615411031, '阪神')
#   (0.33801421281637223, '席')
#   (0.3055495856023897, 'オファー')
#   (0.2599285356789757, '楽天')
#   (0.2026322040398884, '監督')
# article_178.txt
# ### Tfidf weight ###
#   (0.366801092836786, '監督')
#   (0.35288839475786987, '楽天')
#   (0.334056998994664, '野村氏')
#   (0.32925650402605394, '星野')
#   (0.3224814518116838, 'キャッチャー')
# article_179.txt
# ### Tfidf weight ###
#   (0.5041958802515699, '世代')
#   (0.3275116664250365, 'ザック')
#   (0.302240134621777, 'ジャパン')
#   (0.25203414699490556, 'jリーグ')
#   (0.16806529341718995, '日本サッカー界')
# article_180.txt
# ### Tfidf weight ###
#   (0.4359867077746995, 'ジャパン')
#   (0.36365571068106906, '一人一人')
#   (0.3543310025184414, 'ザック')
#   (0.3043244994794621, '判断')
#   (0.20288299965297474, 'ポイント')
# article_181.txt
# ### Tfidf weight ###
#   (0.5597893947628927, '川島')
#   (0.27989469738144634, '特別')
#   (0.25735455479591485, '場所')
#   (0.25439497447297404, '負傷')
#   (0.23151751108958846, 'スタート')
# article_182.txt
# ### Tfidf weight ###
#   (0.43057805100339214, 'メジャー')
#   (0.3778656602578502, 'お金')
#   (0.275067717201396, '野村氏')
#   (0.27111491514538083, 'チャンピオン')
#   (0.2655362320100611, 'メジャー挑戦')
# article_183.txt
# ### Tfidf weight ###
#   (0.43517550830001905, '成長')
#   (0.4029979530282095, '遠藤')
#   (0.22409323403382606, '独特')
#   (0.2212118410045184, '日本代表')
#   (0.21834712872814738, '遠藤保仁')
# article_184.txt
# ### Tfidf weight ###
#   (0.25321245905324824, 'サンデー・ジャポン')
#   (0.2480021515560908, '体力')
#   (0.24334137267925937, '賛否')
#   (0.24334137267925937, 'スポーツ選手')
#   (0.23912518533426133, 'テリー伊藤')
# article_185.txt
# ### Tfidf weight ###
#   (0.3870572214370491, 'ジャパン')
#   (0.29643186905230207, '本田')
#   (0.2796137708036401, 'ザック')
#   (0.24652621639154373, '裏')
#   (0.2041705759618986, '本田圭佑')
# article_186.txt
# ### Tfidf weight ###
#   (0.3144479267789147, '北海道日本ハムファイターズ')
#   (0.29591203295288776, '自身')
#   (0.2805179854580714, 'ダルビッシュ')
#   (0.24285609477056538, 'ブログ')
#   (0.2061650813016976, '記述')
# article_187.txt
# ### Tfidf weight ###
#   (0.3632156456298925, '合意')
#   (0.30785549876446333, 'お願い')
#   (0.2820303292910499, 'つもり')
#   (0.24422663958803015, '顔')
#   (0.19827366040786637, '気')
# article_188.txt
# ### Tfidf weight ###
#   (0.4559429524246912, '一つ')
#   (0.38340370586220796, '母')
#   (0.23717783231242695, '今年6月')
#   (0.23717783231242695, 'リング')
#   (0.2310962171913114, '日記')
# article_189.txt
# ### Tfidf weight ###
#   (0.5082332969159309, 'ドラフト')
#   (0.3967964205022225, '楽天')
#   (0.27766810448865054, '目玉')
#   (0.24717498219141742, '復帰')
#   (0.216897935584397, '斎藤')
# article_190.txt
# ### Tfidf weight ###
#   (0.636009379254537, '長谷部')
#   (0.3131329168366541, '人物')
#   (0.19483271735931768, '同誌')
#   (0.17428299442436032, 'フジテレビ')
#   (0.16068672032719314, '真相')
# article_191.txt
# ### Tfidf weight ###
#   (0.42438347717883174, '性格')
#   (0.37135712963461676, '男')
#   (0.2986866859197477, 'ブログ')
#   (0.26762965392602195, '毎日')
#   (0.23731825075060253, '間違い')
# article_192.txt
# ### Tfidf weight ###
#   (0.735287035948046, 'ロッテ')
#   (0.24966936908186385, '阪神')
#   (0.20891145761163135, '引退')
#   (0.18647195703747754, '野球')
#   (0.154448271751785, '恩返し')
# article_193.txt
# ### Tfidf weight ###
#   (0.4095301061836624, '中日')
#   (0.3081370036695828, 'マウンド')
#   (0.281513653139657, '阪神')
#   (0.27571524282320786, '球場')
#   (0.2730200707891083, '球')
# article_194.txt
# ### Tfidf weight ###
#   (0.37478200190707056, '試合')
#   (0.23505640330836272, '観衆')
#   (0.23505640330836272, 'プロレス界')
#   (0.22380817099329833, '伝説')
#   (0.2192029102742503, '芸能界')
# article_195.txt
# ### Tfidf weight ###
#   (0.38209408280418694, '何回')
#   (0.28251575229826775, '好き')
#   (0.2750683726857579, 'テレビ')
#   (0.2696284022648068, '日')
#   (0.21246931424186447, '雑誌')
# article_196.txt
# ### Tfidf weight ###
#   (0.4155819941266507, '離婚')
#   (0.3477788981187957, '性格')
#   (0.2827302835402519, 'ダルビッシュ')
#   (0.2690116999949256, 'テレビ')
#   (0.2636915111394296, '報道')
# article_197.txt
# ### Tfidf weight ###
#   (0.43648229086147494, '岩隈')
#   (0.334124892011796, 'もん')
#   (0.25404657093800465, '恩師')
#   (0.23245991331255275, '大丈夫')
#   (0.2153256192196485, '興味')
# article_198.txt
# ### Tfidf weight ###
#   (0.5910860486906758, '斎藤')
#   (0.25811599674748525, '指揮')
#   (0.25223191157846575, '悩み')
#   (0.25223191157846575, 'ドラフト会議')
#   (0.25223191157846575, 'ストレス')
# article_199.txt
# ### Tfidf weight ###
#   (0.41011344514641146, 'センター')
#   (0.3995974871200739, 'フォアボール')
#   (0.19979874356003696, 'シリーズ')
#   (0.19524407496690643, '警戒')
#   (0.19524407496690643, '延長戦')
# article_200.txt
# ### Tfidf weight ###
#   (0.4951383421790405, '澤村')
#   (0.2744384620014229, '涙')
#   (0.21294468139664072, '巨人')
#   (0.17334106158283152, '東京ドーム')
#   (0.16889632232978147, '運命')
# article_201.txt
# ### Tfidf weight ###
#   (0.39689951931196377, '女')
#   (0.23713959443167926, '週刊文春')
#   (0.23713959443167926, '柔道家')
#   (0.23713959443167926, '政治家')
#   (0.23105895979036442, '和田アキ子')
# article_202.txt
# ### Tfidf weight ###
#   (0.4526956267626195, 'プロ野球')
#   (0.36570378910950335, 'メジャー')
#   (0.2692797256490725, '日本')
#   (0.21204662604370791, '夢')
#   (0.20872780904420435, 'ノムさん')
# article_203.txt
# ### Tfidf weight ###
#   (0.40003606194149677, '石川')
#   (0.3844412901245835, 'フォーム')
#   (0.37778037387975566, '桑田氏')
#   (0.2666907079609978, '石川遼')
#   (0.21955905871698464, '緊張')
# article_204.txt
# ### Tfidf weight ###
#   (0.5766251474995036, '騎手')
#   (0.4767326178873166, '交際')
#   (0.2809197829015138, '三浦皇成')
#   (0.18293761358053717, '報道')
#   (0.1698116511584515, 'ブログ')
# article_205.txt
# ### Tfidf weight ###
#   (0.5100992365263564, '交際')
#   (0.4405939201521601, '里田')
#   (0.32066006205782177, 'タレント')
#   (0.29372928010144006, '付き合い')
#   (0.26147234199576164, '田中将大')
# article_206.txt
# ### Tfidf weight ###
#   (0.6316657272740488, '紗栄子')
#   (0.5286081055374786, 'ダル')
#   (0.20047947231753743, '証言')
#   (0.174079386523988, '違い')
#   (0.17018382250833416, '子供')
# article_207.txt
# ### Tfidf weight ###
#   (0.4061947891383038, 'チームメイト')
#   (0.33511465719183764, '素顔')
#   (0.33511465719183764, '澤村')
#   (0.2732881738627337, 'vtr')
#   (0.2684066070803867, '意外')
# article_208.txt
# ### Tfidf weight ###
#   (0.5881801656355073, '解雇')
#   (0.3847508794860517, '行為')
#   (0.2795511885421023, '目標')
#   (0.20484889820674157, '地域')
#   (0.20484889820674157, '全力')
# article_209.txt
# ### Tfidf weight ###
#   (0.4203580896272017, '闘莉王')
#   (0.26951509132202367, '試合')
#   (0.23906461254100392, '監督')
#   (0.23131331893561338, '優勝')
#   (0.22537990149337755, 'マネジメント')
# article_210.txt
# ### Tfidf weight ###
#   (0.3996113905880824, '場合')
#   (0.35653084851877653, '星野')
#   (0.2721611876476854, '仕事')
#   (0.24238609809753092, 'ノムさん')
#   (0.18722475267404726, '非難')
# article_211.txt
# ### Tfidf weight ###
#   (0.4794126420308548, '安藤')
#   (0.3686620896523238, '写真')
#   (0.24534353469156606, '掲載')
#   (0.2296493635933731, '安藤美姫')
#   (0.19550088474918065, '本人')
# article_212.txt
# ### Tfidf weight ###
#   (0.32307147175566, '父親')
#   (0.3147874077321634, '三浦')
#   (0.307611425070992, 'デスク')
#   (0.29561968122926013, '両親')
#   (0.20400644698428572, '状況')
# article_213.txt
# ### Tfidf weight ###
#   (0.3268594395242667, '岩隈')
#   (0.3184081981213725, '星野監督')
#   (0.30082918343686726, '発表')
#   (0.29543980190139546, '風')
#   (0.1902425860759868, '松井稼頭央')
# article_214.txt
# ### Tfidf weight ###
#   (0.47772765980322607, '星野監督')
#   (0.3805770746574864, '週刊文春')
#   (0.36236519321420935, '星野')
#   (0.23072493317803347, '同誌')
#   (0.22503076730474955, 'コメント')
# article_215.txt
# ### Tfidf weight ###
#   (0.2948679894835402, '練習')
#   (0.2522983596741323, 'スポット')
#   (0.24022504228144947, 'おかげ')
#   (0.2352819745371376, '決勝トーナメント')
#   (0.2352819745371376, 'インパクト')
# article_216.txt
# ### Tfidf weight ###
#   (0.43420984276287794, 'お金')
#   (0.3227517120071788, '夢')
#   (0.3162187478493436, '金')
#   (0.3162187478493436, '岩隈')
#   (0.23706264447328923, '野村氏')
# article_217.txt
# ### Tfidf weight ###
#   (0.695747018063574, '里田')
#   (0.45309581829119067, '交際')
#   (0.17799436432105084, 'アプローチ')
#   (0.16161591245791335, '高校時代')
#   (0.12908847840216692, '周囲')
# article_218.txt
# ### Tfidf weight ###
#   (0.2668291390285048, 'リング')
#   (0.2553227490722938, 'ファン')
#   (0.24883271843605154, '経過')
#   (0.24415633046653434, '冗談')
#   (0.24415633046653434, '今月')
# article_219.txt
# ### Tfidf weight ###
#   (0.40675588481003416, '一切')
#   (0.37330706999614194, '朝')
#   (0.3037289106247785, 'ツイート')
#   (0.22741107727528925, 'オーナー')
#   (0.22333106214554807, '自身')
# article_220.txt
# ### Tfidf weight ###
#   (0.3607019440359393, '名前')
#   (0.27425401161002794, '相方')
#   (0.2672217045526084, '最大')
#   (0.2672217045526084, 'ブーム')
#   (0.2611300430964749, '結成')
# article_221.txt
# ### Tfidf weight ###
#   (0.5954512799773328, 'パンチ')
#   (0.3331744678990799, '距離')
#   (0.28282058269673693, 'タイミング')
#   (0.23818051199093315, '激闘')
#   (0.2221163119327199, '真剣')
# article_222.txt
# ### Tfidf weight ###
#   (0.6566801872667576, '紗栄子')
#   (0.24495602951854017, '日ハム')
#   (0.20210051564838438, 'メール')
#   (0.1986031980894157, '心配')
#   (0.19235067231019065, '男')
# article_223.txt
# ### Tfidf weight ###
#   (0.23821793215093642, '選択肢')
#   (0.23821793215093642, 'fa')
#   (0.23210964722327246, '独占インタビュー')
#   (0.23210964722327246, '即答')
#   (0.22215120827189722, '国内')
# article_224.txt
# ### Tfidf weight ###
#   (0.5085149124858703, '一番最初')
#   (0.3211064102039518, 'コーナー')
#   (0.25425745624293516, 'ポーズ')
#   (0.24773789252373177, 'オーナー')
#   (0.23265287942708066, '大勢')
# article_225.txt
# ### Tfidf weight ###
#   (0.3470035059349843, '斎藤佑樹')
#   (0.24217529385104244, '冗談交じり')
#   (0.23596553590408134, '和田毅')
#   (0.23058639889704313, '素直')
#   (0.23058639889704313, '上田晋也')
# article_226.txt
# ### Tfidf weight ###
#   (0.3451040357558914, '健闘')
#   (0.29910799660752374, 'ビックリ')
#   (0.28734727019738826, '風')
#   (0.2847274415563028, '課題')
#   (0.2395467346159744, '成長')
# article_227.txt
# ### Tfidf weight ###
#   (0.42310684287443706, '材料')
#   (0.3904589737081475, '佑ちゃん')
#   (0.28109023230671804, 'ノムさん')
#   (0.27965984543964495, '野村氏')
#   (0.25277217908542055, '今日')
# article_228.txt
# ### Tfidf weight ###
#   (0.45614214757816546, 'フォロー')
#   (0.37971508595471215, 'ダルビッシュ')
#   (0.2175309107815012, '綺麗')
#   (0.18245685903126618, '騒動')
#   (0.13900444203224685, '週刊アサヒ芸能')
# article_229.txt
# ### Tfidf weight ###
#   (0.33052649503364356, '自分')
#   (0.23680310505544414, '今年')
#   (0.19895150432947464, '苦手')
#   (0.19895150432947464, '宮根誠司')
#   (0.19895150432947464, 'スイング')
# article_230.txt
# ### Tfidf weight ###
#   (0.4975248017288912, '坂本')
#   (0.4221601959503798, 'ホームラン')
#   (0.2487624008644456, 'cs')
#   (0.22956733830828485, '打率')
#   (0.19143324019764596, '意識')
# article_231.txt
# ### Tfidf weight ###
#   (0.448134571808683, 'プロレス')
#   (0.38973136489927374, '女性')
#   (0.3799033340385692, '全日本プロレス')
#   (0.2277329889442736, '骨折')
#   (0.2277329889442736, '怪我')
# article_232.txt
# ### Tfidf weight ###
#   (0.532431230812408, 'dynamite')
#   (0.2502267654748462, '練習')
#   (0.24550796295282973, '出場')
#   (0.24523507861851107, '選手達')
#   (0.22829828128070562, 'オファー')
# article_233.txt
# ### Tfidf weight ###
#   (0.3503093795297452, 'シーズン')
#   (0.3432379579538687, '実感')
#   (0.33095213002984325, '前田')
#   (0.28579350000976156, 'ストレート')
#   (0.2675186169458379, '成績')
# article_234.txt
# ### Tfidf weight ###
#   (0.33884172525993095, '当時')
#   (0.3280286731620996, '真面目')
#   (0.31961749864628647, '仲間')
#   (0.28583985446158117, '高校')
#   (0.2609595414194726, '監督')
# article_235.txt
# ### Tfidf weight ###
#   (0.7685192045656017, '里田')
#   (0.32563464906559286, '結婚')
#   (0.2773538248777444, 'マー君')
#   (0.1614287443544708, '熱愛報道')
#   (0.14679931635813703, '同誌')
# article_236.txt
# ### Tfidf weight ###
#   (0.5167672850004932, '斎藤')
#   (0.2646217763229931, 'ロッテ')
#   (0.24587724403450642, '指名')
#   (0.24587724403450642, 'ヤクルト')
#   (0.23875090359846723, '本音')
# article_237.txt
# ### Tfidf weight ###
#   (0.34794313320588427, '放題')
#   (0.28210213540675455, '身体')
#   (0.2367409941713004, '一緒')
#   (0.22619653402693546, '対戦')
#   (0.18822623656008167, '気持ち')
# article_238.txt
# ### Tfidf weight ###
#   (0.43308079592124255, '日本一')
#   (0.30481265739554586, '野村氏')
#   (0.23664873993771782, 'ペナントレース')
#   (0.2253243090078585, '一週間')
#   (0.21278857033052986, 'システム')
# article_239.txt
# ### Tfidf weight ###
#   (0.516803983458551, '岩隈')
#   (0.4207634913279005, '交渉')
#   (0.3007963498029156, '要求')
#   (0.26210996746541215, '一切')
#   (0.19085871174818728, '必要')
# article_240.txt
# ### Tfidf weight ###
#   (0.501994505797661, 'テレビ東京')
#   (0.34642458797397485, '結婚')
#   (0.34347012156491413, 'データ')
#   (0.31428503203027336, 'アナウンサー')
#   (0.2807029138977367, 'プロ野球選手')
# article_241.txt
# ### Tfidf weight ###
#   (0.4946467963707734, 'ドイツ')
#   (0.38140618665581416, '日本人選手')
#   (0.32032487118346703, '移籍')
#   (0.24090410945691582, '在籍')
#   (0.22937604491289118, '槙野')
# article_242.txt
# ### Tfidf weight ###
#   (0.43797495459411695, '松坂')
#   (0.3579375271673009, 'プロ野球選手')
#   (0.24399689502641347, '期待')
#   (0.21898747729705847, '格闘技イベント')
#   (0.21337229167755925, '松坂大輔')
# article_243.txt
# ### Tfidf weight ###
#   (0.34813717914667747, '予定')
#   (0.2905455861665571, '試合')
#   (0.2429664894397818, '当日')
#   (0.2429664894397818, '大相撲')
#   (0.2429664894397818, 'スウェーデン')
# article_244.txt
# ### Tfidf weight ###
#   (0.4150862477540922, '魔裟斗')
#   (0.3198661558213382, '膝')
#   (0.2504422451098877, '解説')
#   (0.24538272891304688, '自ら')
#   (0.20117377704865325, '勝利')
# article_245.txt
# ### Tfidf weight ###
#   (0.5571479758437784, 'カズ')
#   (0.459022376058564, '息子')
#   (0.21709696783863802, '下')
#   (0.18331889223277392, '部分')
#   (0.16183509835444448, '時')
# article_246.txt
# ### Tfidf weight ###
#   (0.4022047717978334, '香川')
#   (0.3730486937843021, 'ドイツ')
#   (0.3318640650815233, 'ゴール')
#   (0.30578163949080367, 'ボール')
#   (0.29696309733260323, '要因')
# article_247.txt
# ### Tfidf weight ###
#   (0.3295925256875284, '回復')
#   (0.30630236677891803, '野球')
#   (0.28465937476416114, 'ボール')
#   (0.24770707855320284, '展開')
#   (0.21061294216348198, '週刊アサヒ芸能')
# article_248.txt
# ### Tfidf weight ###
#   (0.41816264563895045, 'オープン戦')
#   (0.392884576548917, '斎藤')
#   (0.25734779472617864, '二軍')
#   (0.24167762487734618, '三振')
#   (0.24167762487734618, 'とんでも')
# article_249.txt
# ### Tfidf weight ###
#   (0.4530605914781024, '補強')
#   (0.4055044642608655, '巨人')
#   (0.3329277836664071, '球団')
#   (0.21367058578558346, 'ノムさん')
#   (0.212583277993778, '野村氏')
# article_250.txt
# ### Tfidf weight ###
#   (0.3960850572274966, 'セルジオ氏')
#   (0.26601938222874316, '日本')
#   (0.25395229211511233, '試合')
#   (0.20963503215016357, '日本代表')
#   (0.20692024053941185, '開催中')
# article_251.txt
# ### Tfidf weight ###
#   (0.43616734632776044, 'コーチ')
#   (0.2558389385154601, 'ルール')
#   (0.22913786716501566, 'イメージ')
#   (0.22150147565747885, '対談')
#   (0.20024968226660922, '球団')
# article_252.txt
# ### Tfidf weight ###
#   (0.36964822571651407, '苦労')
#   (0.3520179962367837, '一生懸命')
#   (0.300460348173308, '対談')
#   (0.2854656535849413, '部分')
#   (0.23826444544385428, '余裕')
# article_253.txt
# ### Tfidf weight ###
#   (0.5734231641683863, 'サッカー')
#   (0.4068731840543153, '部分')
#   (0.3062425551672909, '大事')
#   (0.18379500298881404, 'プレー')
#   (0.14339880416543313, '他')
# article_254.txt
# ### Tfidf weight ###
#   (0.30688989405826006, 'ところ')
#   (0.28525744802686154, 'ホームラン')
#   (0.27887393144905265, '松井')
#   (0.22689305490973602, '存在')
#   (0.2189248851038037, 'シーズン')
# article_255.txt
# ### Tfidf weight ###
#   (0.37021331967542315, 'シリア')
#   (0.2740898348500545, '日本代表')
#   (0.2503809313092545, 'チャンス')
#   (0.23266499008310787, '場面')
#   (0.23094975332689535, '時')
# article_256.txt
# ### Tfidf weight ###
#   (0.36582512748186247, '佑ちゃん')
#   (0.2914764449678611, '斎藤佑樹')
# ...
#   (0.6206723739447286, 'マイク')
#   (0.2261030529660998, 'ハーフナー・マイク')
#   (0.21085342298479187, '変')
#   (0.20689079131490956, '汗')
#   (0.17109755511723604, '番組')
# article_817.txt
# ### Tfidf weight ###
#   (0.383894754969295, '可憐')
#   (0.2368443418271166, '目')
#   (0.19711944594792294, '活躍')
#   (0.19699873699003795, '格闘家')
#   (0.1919473774846475, '耳')
# article_818.txt
# ### Tfidf weight ###
#   (0.28472812226463634, '予想')
#   (0.273710186964282, '非常')
#   (0.26262710260093225, '記録')
#   (0.25774352783770493, 'ドイツ')
#   (0.21632195886203187, '選手')
# article_819.txt
# ### Tfidf weight ###
#   (0.3710117077472787, '友達')
#   (0.317896551326134, '言葉')
#   (0.2716860992760213, '子')
#   (0.24666303484739788, 'エピソード')
#   (0.19555934940622197, '発表')
# article_820.txt
# ### Tfidf weight ###
#   (0.6517690658800929, 'レフェリー')
#   (0.3724394662171959, 'ファール')
#   (0.2511661214799211, 'フリーキック')
#   (0.24712322712673543, '内田')
#   (0.18621973310859796, '辺り')
# article_821.txt
# ### Tfidf weight ###
#   (0.34254216415987165, 'ファール')
#   (0.3145187868537201, '普通')
#   (0.2984867188790785, 'オーストラリア')
#   (0.28320135423310366, 'アウェー')
#   (0.20533684201794325, 'フリーキック')
# article_822.txt
# ### Tfidf weight ###
#   (0.3170636900187165, '美女アスリート')
#   (0.3092754380335153, 'スタイル')
#   (0.30235444473622497, 'モデル')
#   (0.24468685934991202, '代表')
#   (0.23429509330687617, '日本')
# article_823.txt
# ### Tfidf weight ###
#   (0.47887820830284694, '松井')
#   (0.39955652114605084, '桑田氏')
#   (0.2886433822679678, '松井秀喜')
#   (0.2449199444823368, '先輩')
#   (0.20035125831193, '引退')
# article_824.txt
# ### Tfidf weight ###
#   (0.27230462864655974, '報道')
#   (0.22022725053018166, '優勝')
#   (0.21457820180456486, 'ロンドン五輪代表')
#   (0.20907607698947078, '木村')
#   (0.20430991968301737, '表彰台')
# article_825.txt
# ### Tfidf weight ###
#   (0.40282502241593465, '前代未聞')
#   (0.39453616395224034, '結末')
#   (0.3146631332563656, '決勝')
#   (0.21153517432242336, '決勝進出')
#   (0.20141251120796733, '我慢')
# article_826.txt
# ### Tfidf weight ###
#   (0.5262848858011107, '奥さん')
#   (0.3624221361790353, '本田')
#   (0.26314244290055533, '離婚')
#   (0.2563950540567142, 'ケンカ')
#   (0.250550199983369, '我慢')
# article_827.txt
# ### Tfidf weight ###
#   (0.3554553501730935, 'さん')
#   (0.33721542648149094, '加藤')
#   (0.27307683321387, '解説')
#   (0.2027842303461837, 'プレー')
#   (0.19731078934033497, 'アピール')
# article_828.txt
# ### Tfidf weight ###
#   (0.707731965536907, '美女')
#   (0.22924835429930043, 'レベル')
#   (0.1923542434496684, '目')
#   (0.18346246391091622, '大会')
#   (0.17704180394452063, 'サッカー')
# article_829.txt
# ### Tfidf weight ###
#   (0.4234184149264264, '石井')
#   (0.35123939151003436, '広島')
#   (0.3288428309169998, '番組')
#   (0.2559498637899714, 'ブログ')
#   (0.20688302457072918, 'トーク')
# article_830.txt
# ### Tfidf weight ###
#   (0.4332818204888404, '長友')
#   (0.36029303724293404, 'カラオケ')
#   (0.23566895379132602, '代表')
#   (0.2287012097295842, '素顔')
#   (0.21305713864522652, '質問')
# article_831.txt
# ### Tfidf weight ###
#   (0.2627301033247631, 'ノムさん')
#   (0.21526107485432372, '監督')
#   (0.2029389432854884, '落合博満氏')
#   (0.2029389432854884, 'うえ')
#   (0.2029389432854884, 'wbc')
# article_832.txt
# ### Tfidf weight ###
#   (0.23135857128413279, '大会')
#   (0.2064775654811396, '注目')
#   (0.20176255610087304, 'プレーヤー')
#   (0.1965890447313887, '開催中')
#   (0.19210754533936406, '途中出場')
# article_833.txt
# ### Tfidf weight ###
#   (0.768126699004187, 'カズ')
#   (0.149024720294913, '武田修宏')
#   (0.149024720294913, '思い出')
#   (0.1452034905301865, '車')
#   (0.1452034905301865, '地元')
# article_834.txt
# ### Tfidf weight ###
#   (0.3661263717314783, 'ピッチャー')
#   (0.35316175862357246, '采配')
#   (0.3160916495978187, '巨人')
#   (0.24499178899735152, '代打')
#   (0.21808713389671672, '信頼')
# article_835.txt
# ### Tfidf weight ###
#   (0.5576917864603151, 'キム・ヨナ')
#   (0.27884589323015757, 'キム')
#   (0.274014546577933, 'ヨナ')
#   (0.26208116118772506, '出場')
#   (0.22487488336199127, '韓国')
# article_836.txt
# ### Tfidf weight ###
#   (0.37226640979846, '目標')
#   (0.3302499370794374, '五輪出場')
#   (0.279896512685373, 'ロンドン')
#   (0.23349942063438822, '舞台')
#   (0.22659754252104264, '自分')
# article_837.txt
# ### Tfidf weight ###
#   (0.5044369071571612, '表情')
#   (0.3490482580921308, '選手')
#   (0.22786318677259476, '彼女たち')
#   (0.22786318677259476, 'ダウンタウンdx')
#   (0.22202041391009406, 'フリーアナウンサー')
# article_838.txt
# ### Tfidf weight ###
#   (0.2948736056804382, '瞬間')
#   (0.23204825008017047, '現在')
#   (0.21671566188371494, '相方')
#   (0.21671566188371494, 'ドキドキ')
#   (0.21671566188371494, 'ダウンタウンdx')
# article_839.txt
# ### Tfidf weight ###
#   (0.268784762826379, '点')
#   (0.25815061808232154, '同社')
#   (0.25329911602780436, '体操')
#   (0.25329911602780436, 'コース')
#   (0.2449038134626453, '水')
# article_840.txt
# ### Tfidf weight ###
#   (0.6589546953586676, '丸山')
#   (0.4543989861294138, '澤')
#   (0.19322742725552564, '助言')
#   (0.1895861184561055, '代表')
#   (0.1425870894479441, 'オリンピック')
# article_841.txt
# ### Tfidf weight ###
#   (0.42586117875775237, '長友')
#   (0.30563749862656286, '成長')
#   (0.30421228548863716, 'インテル')
#   (0.2963466063877594, 'イタリア')
#   (0.208861697079848, '加藤')
# article_842.txt
# ### Tfidf weight ###
#   (0.30704699851545764, '試合')
#   (0.29371886566822664, '前半')
#   (0.2864583502035886, '決勝')
#   (0.23870785105154363, '内容')
#   (0.23763108622257278, '一戦')
# article_843.txt
# ### Tfidf weight ###
#   (0.31112405119681513, 'ダメ')
#   (0.23001405742471157, 'ミドルシュート')
#   (0.21900711816575597, 'ロスタイム')
#   (0.21900711816575597, 'リズム')
#   (0.21900711816575597, 'ボランチ')
# article_844.txt
# ### Tfidf weight ###
#   (0.3621577878248982, 'カタチ')
#   (0.3480396404872882, '采配')
#   (0.2926493029640248, '失点')
#   (0.2764565648660605, 'メンバー')
#   (0.2652622740535952, '苦言')
# article_845.txt
# ### Tfidf weight ###
#   (0.3800425791176732, '審判')
#   (0.2877872629626494, 'アウト')
#   (0.2021029955017566, 'ツイッター')
#   (0.16002855098008129, '裁定')
#   (0.16002855098008129, '自分たち')
# article_846.txt
# ### Tfidf weight ###
#   (0.44678965522440445, '中村')
#   (0.43775951819497716, '金メダル')
#   (0.29269898479008233, '女王')
#   (0.2527600209278557, '父')
#   (0.21641809597791342, '目標')
# article_847.txt
# ### Tfidf weight ###
#   (0.4398316979333733, '元気')
#   (0.39580282741938483, '秘密')
#   (0.2942793337248347, '瞬間')
#   (0.2564955188913061, 'ところ')
#   (0.22391550424680384, '父')
# article_848.txt
# ### Tfidf weight ###
#   (0.2946279232153754, 'フォーム')
#   (0.2848628257356589, '躍進')
#   (0.2848628257356589, '美女')
#   (0.2602503878518986, '不安')
#   (0.25940013428891856, '紹介')
# article_849.txt
# ### Tfidf weight ###
#   (0.3695335236713466, 'カナダ')
#   (0.25283887140563177, 'スウェーデン')
#   (0.24073968872513146, '警戒')
#   (0.23578603119296343, '南アフリカ')
#   (0.20661979094022187, '中')
# article_850.txt
# ### Tfidf weight ###
#   (0.5150149281988393, '入籍')
#   (0.2690508285524228, '照れ笑い')
#   (0.2690508285524228, 'キャスター')
#   (0.26291746986893716, '拍手')
#   (0.26291746986893716, 'フジ')
# article_851.txt
# ### Tfidf weight ###
#   (0.4113651435676334, '川澄奈穂美')
#   (0.29954076954279535, 'なでしこジャパン')
#   (0.28797845009248113, '川澄')
#   (0.17533163361106238, '期待')
#   (0.15736033087921986, '女性誌')
# article_852.txt
# ### Tfidf weight ###
#   (0.3608777496359752, '妻')
#   (0.3485700770826276, 'エラー')
#   (0.21042172793866423, '野球')
#   (0.19446674629513402, 'イタリア')
#   (0.18584128012495502, '北京五輪')
# article_853.txt
# ### Tfidf weight ###
#   (0.5343189800298837, '可憐')
#   (0.3655868797481969, '花')
#   (0.3140609184217885, '妹')
#   (0.18279343987409846, '正真正銘')
#   (0.18279343987409846, 'ロンドン五輪代表')
# article_854.txt
# ### Tfidf weight ###
#   (0.4885354794889942, 'オリンピック')
#   (0.47288620083841093, '北島')
#   (0.281371368343142, '勝負')
#   (0.1891544803353644, '松岡氏')
#   (0.17639686474114513, '北島康介')
# article_855.txt
# ### Tfidf weight ###
#   (0.4156628258675949, '会場')
#   (0.288545560716054, 'スタジアム')
#   (0.2776794370592334, '?')
#   (0.2771085505783966, 'みの')
#   (0.25252655418037173, '意外')
# article_856.txt
# ### Tfidf weight ###
#   (0.36906840727535734, '兄')
#   (0.3596049090026554, '姉')
#   (0.2814559933587954, '意外')
#   (0.2353256430722489, 'ほう')
#   (0.2341781102253497, 'なでしこジャパン')
# article_857.txt
# ### Tfidf weight ###
#   (0.36900986069361447, '奇跡')
#   (0.35317785106310573, 'スペイン')
#   (0.32534379299885013, '加藤浩次')
#   (0.2940698481687655, '選手たち')
#   (0.1893604316092472, '研究')
# article_858.txt
# ### Tfidf weight ###
#   (0.5107381904094279, 'チケット')
#   (0.2824009676288262, '五輪')
#   (0.2682035279075147, 'イギリス')
#   (0.25100063812910794, '人')
#   (0.24541393578863235, 'とんでも')
# article_859.txt
# ### Tfidf weight ###
#   (0.3109237931318362, '前')
#   (0.27940362062204155, 'ジャンプ')
#   (0.2669385053028376, '直前')
#   (0.20218605180315585, 'とき')
#   (0.17494557698506988, '説明')
# article_860.txt
# ### Tfidf weight ###
#   (0.43677140656555263, 'メダル')
#   (0.2910709887766409, 'とき')
#   (0.26815660591466406, '銀メダル')
#   (0.23156646536216427, '父')
#   (0.16500155263080715, '獲得')
# article_861.txt
# ### Tfidf weight ###
#   (0.44184855282629076, '松岡氏')
#   (0.29456570188419384, '高校生')
#   (0.26028036028037743, '?」')
#   (0.21908641671919718, 'スタート')
#   (0.21570587896361867, 'メダル')
# article_862.txt
# ### Tfidf weight ###
#   (0.3810474345152645, 'ポイント')
#   (0.3386614877781438, '決勝')
#   (0.26451618670042953, '準決勝')
#   (0.2427641893117458, '申し訳')
#   (0.20411257644284583, '頭')
# article_863.txt
# ### Tfidf weight ###
#   (0.40188618751789923, '競泳')
#   (0.25223366355911747, 'ロンドン五輪')
#   (0.24489436876307455, '登場')
#   (0.20623118792310677, '泳ぎ')
#   (0.20623118792310677, 'タイム')
# article_864.txt
# ### Tfidf weight ###
#   (0.4799611937692124, 'そう')
#   (0.31667410963401343, '苦手')
#   (0.3094551171833717, 'リラックス')
#   (0.27198209930123096, 'ロシア')
#   (0.27198209930123096, 'みの')
# article_865.txt
# ### Tfidf weight ###
#   (0.3812771601244205, 'ブーイング')
#   (0.34400141880255836, '判定')
#   (0.3394058364654552, '一度')
#   (0.3351069562853677, '会場')
#   (0.3109339940518422, '皆さん')
# article_866.txt
# ### Tfidf weight ###
#   (0.31462050893102206, '加藤浩次')
#   (0.31462050893102206, '判定')
#   (0.3064857159596228, '柔道')
#   (0.3064857159596228, '会場')
#   (0.29289170965768796, '納得')
# article_867.txt
# ### Tfidf weight ###
#   (0.4772692925041265, '泳ぎ')
#   (0.33284727370880646, '記録')
#   (0.2985404370661532, '舞台')
#   (0.2918651232263395, 'ロンドン五輪')
#   (0.24491701199546728, '優勝')
# article_868.txt
# ### Tfidf weight ###
#   (0.4725132212227387, '一本')
#   (0.32410594591810676, '柔道')
#   (0.30359025120726973, '全部')
#   (0.20583815448686912, '試合')
#   (0.1920359372615444, '決勝')
# article_869.txt
# ### Tfidf weight ###
#   (0.4599438388852424, 'レース')
#   (0.36176885814862847, '北島')
#   (0.33102890188166967, '隣')
#   (0.21960399623124416, '自分')
#   (0.18088442907431423, '泳ぎ')
# article_870.txt
# ### Tfidf weight ###
#   (0.3868594073280412, '選手')
#   (0.3697401140951937, '完璧')
#   (0.3697401140951937, '体操')
#   (0.3302324859091771, '中国')
#   (0.27170042822898416, '金メダル')
# article_871.txt
# ### Tfidf weight ###
#   (0.36716556720285165, '柔道')
#   (0.3627410704935142, 'スタイル')
#   (0.3059827567678927, '苦言')
#   (0.26233325601703944, '試合')
#   (0.21937414750891882, 'イギリス')
# article_872.txt
# ### Tfidf weight ###
#   (0.3231827701264913, 'とき')
#   (0.25979315937487246, '時間')
#   (0.25125386461160987, '自分')
#   (0.2419767738280023, '圧力')
#   (0.22724256112805724, '先生')
# article_873.txt
# ### Tfidf weight ###
#   (0.4093646077437645, 'アウェー')
#   (0.33009408693619646, 'お母さん')
#   (0.32162995194124644, 'カナダ')
#   (0.2920346290460152, '加藤')
#   (0.28763962875234583, '準決勝')
# article_874.txt
# ### Tfidf weight ###
#   (0.5215776533335137, '銀メダル')
#   (0.2900313072485985, '北島')
#   (0.2704700051763116, '北島康介')
#   (0.25659104048248743, '銅メダル')
#   (0.2407020395526356, '獲得')
# article_875.txt
# ### Tfidf weight ###
#   (0.4999079794045604, '名前')
#   (0.2895265620041744, '指')
#   (0.27823982788456203, '体操')
#   (0.2690178946326818, '技')
#   (0.2294625543806098, '最後')
# article_876.txt
# ### Tfidf weight ###
#   (0.36867842870272094, 'ドイツ')
#   (0.35910936528548715, 'ギャグ')
#   (0.23615232721586057, '披露')
#   (0.17955468264274357, '絆')
#   (0.17955468264274357, '死闘')
# article_877.txt
# ### Tfidf weight ###
#   (0.4410235167345225, '復活')
#   (0.29850810119312066, '銅メダル')
#   (0.23531034765273284, '記録')
#   (0.17264810590927523, '注目')
#   (0.1687056076676353, '高校生')
# article_878.txt
# ### Tfidf weight ###
#   (0.5531554279204765, 'メキシコ')
#   (0.31419634834839283, '韓国')
#   (0.23754448176953608, 'みの')
#   (0.1777859730255022, '日本')
#   (0.16523285458878925, '意味')
# article_879.txt
# ### Tfidf weight ###
#   (0.3472016509120334, '男性')
#   (0.29428230501470526, '問い')
#   (0.23345881016388567, '顔')
#   (0.23083318162111865, 'エピソード')
#   (0.22138294735062847, 'ほう')
# article_880.txt
# ### Tfidf weight ###
#   (0.4721430064766303, '予選')
#   (0.3761281151250041, '兄')
#   (0.3327609882195157, '加藤')
#   (0.2640257183103011, '五輪')
#   (0.18806405756250205, '弟')
# article_881.txt
# ### Tfidf weight ###
#   (0.3560061231913573, '金メダル')
#   (0.3229776399086739, '吉田')
#   (0.276684639865302, '緊張')
#   (0.24616099220964227, '記録')
#   (0.22182818250858974, '経験')
# article_882.txt
# ### Tfidf weight ###
#   (0.5831833889254877, '目')
#   (0.27239930508593374, 'プレッシャー')
#   (0.2571674774296263, '?」')
#   (0.20208456085358265, '相手')
#   (0.19402851706839916, '重圧')
# article_883.txt
# ### Tfidf weight ###
#   (0.3282948079797928, 'キュート')
#   (0.2921626366804162, '獲得')
#   (0.2661718468783501, 'アスリート')
#   (0.2639618337814636, '競技')
#   (0.23671090800545275, '金メダル')
# article_884.txt
# ### Tfidf weight ###
#   (0.42281574362198227, '帰国')
#   (0.2653722157721454, 'チームメイト')
#   (0.25861474665933776, '参加')
#   (0.2015510847068202, '練習')
#   (0.17399952071991437, '番組')
# article_885.txt
# ### Tfidf weight ###
#   (0.4732145186889043, '嫌')
#   (0.2841341984745111, 'うち')
#   (0.28236255485019573, '関係')
#   (0.24150002863884834, '二人')
#   (0.19520329340640297, '維持')
# article_886.txt
# ### Tfidf weight ###
#   (0.5947735263727388, '応援')
#   (0.41799231326338454, 'イギリス')
#   (0.3060892655043785, 'メダル')
#   (0.21069264207189775, '日本人')
#   (0.13933077108779485, 'アテネ')
# article_887.txt
# ### Tfidf weight ###
#   (0.34818139353045074, 'ポジション')
#   (0.2883590770574571, 'プレッシャー')
#   (0.2206291840581478, '紹介')
#   (0.20539657429383, '独特')
#   (0.20539657429383, 'なでしこジャパンメンバー')
# article_888.txt
# ### Tfidf weight ###
#   (0.30484086123290993, 'なでしこジャパン')
#   (0.2561449744252957, '美貌')
#   (0.24583066588059846, '注目')
#   (0.23634908598059817, '実力')
#   (0.23634908598059817, 'メディア')
# article_889.txt
# ### Tfidf weight ###
#   (0.4988322863378943, '骨折')
#   (0.4765777358768058, '病院')
#   (0.2992993718027366, 'プロレスラー')
#   (0.2584597809070265, '妻')
#   (0.20694010980819363, '行列')
# article_890.txt
# ### Tfidf weight ###
#   (0.3671336363740028, '危機')
#   (0.26384868870364847, 'もん')
#   (0.20061317254173475, '自分たち')
#   (0.20061317254173475, 'ハプニング')
#   (0.19546913318641407, '北京五輪時')
# article_891.txt
# ### Tfidf weight ###
#   (0.38553632264283144, '魅力')
#   (0.38553632264283144, '金メダリスト')
#   (0.3187701052737592, '紹介')
#   (0.2919832862297794, 'オリンピック')
#   (0.26605721811301664, '金メダル')
# article_892.txt
# ### Tfidf weight ###
#   (0.4293719652209431, 'プロレスラー')
#   (0.3174724478325555, 'エピソード')
#   (0.258961150131725, '話')
#   (0.2387589107259941, '現場')
#   (0.2387589107259941, 'レスラー')
# article_893.txt
# ### Tfidf weight ###
#   (0.2967766654419778, 'フジテレビ')
#   (0.2453137815878653, '顔')
#   (0.18241622558384069, '本')
#   (0.18241622558384069, 'プッシュ')
#   (0.17773878475797905, '方法')
# article_894.txt
# ### Tfidf weight ###
#   (0.34319083062372396, '人気')
#   (0.33630150490826044, '本')
#   (0.2683758434693942, 'プレー')
#   (0.26622101806987025, 'ベンチ')
#   (0.24265802535873815, 'ルックス')
# article_895.txt
# ### Tfidf weight ###
#   (0.589189399774124, '槙原氏')
#   (0.4130747413902295, '達成')
#   (0.3104602710229582, '巨人')
#   (0.26105124206097946, '当時')
#   (0.2520277730289873, 'エピソード')
# article_896.txt
# ### Tfidf weight ###
#   (0.6735871247237525, '石川')
#   (0.3883970389819191, '進化')
#   (0.269434849889501, '石川遼')
#   (0.1452129595083709, '優勝')
#   (0.1347174249447505, '焦り')
# article_897.txt
# ### Tfidf weight ###
#   (0.7446377141857352, '吉田')
#   (0.32551445999319273, '吉田麻也')
#   (0.17157786314912687, '発表')
#   (0.1585838769417699, 'オランダ')
#   (0.14892754283714704, '公式サイト')
# article_898.txt
# ### Tfidf weight ###
#   (0.554566359334706, '吉田')
#   (0.2424257669874087, '吉田麻也')
#   (0.24176113918373085, '移籍')
#   (0.23620958651268137, '李忠成')
#   (0.23620958651268137, 'ステップ')
# article_899.txt
# ### Tfidf weight ###
#   (0.44474551880956564, '先発')
#   (0.39310656509327213, '巨人戦')
#   (0.38272217937773617, 'ピッチャー')
#   (0.2263430555688158, 'ボール')
#   (0.21083738653582582, '若手')
# article_900.txt
# ### Tfidf weight ###
#   (0.3358339635086389, '監督')
#   (0.3084672649750371, '日本')
#   (0.2180310384076584, '本田')
#   (0.20709566571529045, '代表')
#   (0.20494576641945345, '成長')
# 4500
# 1569

# %%
tv_vocab2
# Out:
# ['韓国代表',
#  '答え',
#  '向こう',
#  '金本',
#  '重圧',
#  '距離',
#  'スポーツ紙記者',
#  '正真正銘',
#  '共通',
#  '波',
#  '生活',
#  '川島',
#  '回復',
#  '下',
#  '野球ファン',
#  '明日',
#  '大型補強',
#  '坂本',
#  '露呈',
#  '内川',
#  '二軍',
#  '泳ぎ',
#  '空振り',
#  '裏',
#  '清武弘嗣',
#  'ピッチャー',
#  '心',
#  '監督',
#  'ファン',
#  '球界',
#  'リリース',
#  '理由',
#  'オーストラリア',
#  '五輪出場',
#  '実施',
#  '世界',
#  '軽率',
#  'アジア',
#  '前半',
#  '非難',
#  'ソフトバンク',
#  '映像',
#  '海外組',
#  'アナウンサー',
#  'ヤツ',
#  '選手達',
#  'オフ',
#  '外国人選手',
#  '三浦皇成',
#  '完敗',
#  'ネット',
#  '一緒',
#  '負けず嫌い',
#  '使用',
#  '告白',
#  '顛末',
#  '指名',
#  '日本人',
#  'サポーター',
#  '行動',
#  '体調不良',
#  '連日',
#  'せい',
#  '宮根誠司',
#  '阿部',
#  '夜',
#  '結局',
#  '移籍',
#  '多く',
#  '酒',
#  '本意',
#  '不思議',
#  '一生',
#  '記録',
#  '責任',
#  '南アフリカ',
#  '笑顔',
#  '事',
#  '会場',
#  '演技',
#  'プレー',
#  '桑田真澄氏',
#  '秋山成勲',
#  '披露',
#  '中西哲生氏',
#  '澤登氏',
#  '矢部浩之',
#  'ファール',
#  '足元',
#  '時間帯',
#  '現在',
#  '秋',
#  '格闘技イベント',
#  '発覚',
#  'ドラフト',
#  '見事優勝',
#  '全日本プロレス',
#  '一切',
#  '運命',
#  '筋肉',
#  '可憐',
#  '食事',
#  '応援',
#  '過言',
#  '年',
#  '楽天',
#  '大量',
#  'ケガ',
#  'マラソン',
#  '途中出場',
#  '澤穂希',
#  '座',
#  '人気',
#  '素直',
#  '北島',
#  'フォーム',
#  '確実',
#  '決定的',
#  '大変',
#  '騎乗',
#  '体力',
#  '馴染み',
#  'ザッケローニ',
#  'タレント',
#  '上機嫌',
#  '番組ゲスト',
#  'セ・リーグ',
#  '指摘',
#  '位置',
#  '真相',
#  'おかげ',
#  '肌',
#  '観衆',
#  'ベテラン',
#  'リラックス',
#  '複雑',
#  '人',
#  'っぱなし',
#  '殺到',
#  'プレーヤー',
#  '疑問',
#  '手術',
#  '苦笑い',
#  '邪魔',
#  'エラー',
#  '行列',
#  'プロレスラー',
#  'アジアカップ',
#  'サッカー',
#  '合意',
#  '場合',
#  '初戦',
#  '材料',
#  'ジャンプ',
#  '引っ張りだこ',
#  '甲子園',
#  '奇跡',
#  '苦悩',
#  'そう',
#  'バイエルン',
#  'つもり',
#  '辺り',
#  'キャンプ',
#  '偉業',
#  '有名',
#  '最大',
#  '浅尾美和',
#  '見通し',
#  '日本人選手',
#  '日本選手権',
#  '美貌',
#  'ドルトムント',
#  'ワンバック',
#  '放題',
#  '長友',
#  'メッシ',
#  'カナダ',
#  'インタビュー',
#  '価値',
#  'ボクシング',
#  '姿',
#  'ブンデスリーガ',
#  '妻',
#  'ゲスト',
#  '資質',
#  'サイドバック',
#  '勝負',
#  '日本代表df長友佑都',
#  '謙虚',
#  '要求',
#  '弟',
#  '胸',
#  '特定',
#  '彼氏',
#  '初日',
#  'スポーツ番組',
#  '今夏',
#  '口',
#  '賛否両論',
#  '知名度',
#  '来年',
#  '上位',
#  'さっき',
#  '一方',
#  '代表入り',
#  'スペイン',
#  '決勝',
#  '体質',
#  '感覚',
#  '番組内',
#  '大丈夫',
#  '冷ややか',
#  '状況',
#  ')“',
#  '怪我',
#  'ルール',
#  '決勝トーナメント',
#  'だめ',
#  'キーマン',
#  'リハビリ',
#  '(5日放送分)',
#  '裏話',
#  '功績',
#  '日本人初',
#  '中',
#  '批判',
#  '一番最初',
#  '所',
#  '病院',
#  '打線',
#  'ジャパン',
#  'コミッショナー',
#  '海外',
#  '記者会見',
#  'マリナーズ',
#  '清武',
#  '姉',
#  '川崎フロンターレ',
#  '素顔',
#  '夢',
#  'イチロー',
#  '賛否',
#  'キレ',
#  'イングランド',
#  '警戒',
#  'お願い',
#  '違い',
#  'アスリート',
#  '国',
#  '納得',
#  '川澄奈穂美',
#  '証言',
#  '感謝',
#  '当日',
#  '関係',
#  '注意',
#  '発表',
#  '私たち',
#  '年俸',
#  'フリー',
#  '引退',
#  '大好き',
#  '情報7days',
#  '巨人戦',
#  '娘',
#  '幸せ',
#  '球団',
#  'ラモスさん',
#  '組織',
#  '愛情',
#  'テリー伊藤',
#  '予想',
#  '心配',
#  '最終予選',
#  '吉田麻也',
#  '田中将大',
#  '維持',
#  'シリア戦',
#  '?」',
#  'ウズベキスタン',
#  '時',
#  'マリノス',
#  '高校',
#  '周囲',
#  '全国',
#  'セルジオ氏',
#  '記事',
#  '苦手',
#  '投球',
#  'ミス',
#  '最初',
#  'サッカー選手',
#  'ドリブル',
#  '立場',
#  '前田',
#  '裁定',
#  '無事',
#  '復帰',
#  '女子w杯ドイツ2011',
#  '春',
#  '種目',
#  '東北楽天ゴールデンイーグルス・田中将大',
#  '充実',
#  '公言',
#  '自分たち',
#  '石井慧',
#  '契約',
#  'ブログ',
#  '男',
#  '参戦',
#  '積極的',
#  '評価',
#  'ニュース',
#  'スポーツジャーナリスト',
#  '熊谷紗希',
#  '全部',
#  '野手',
#  '勉強',
#  '目標',
#  '先制',
#  '開幕戦',
#  '一言',
#  '顔',
#  'チケット',
#  'mc',
#  '岡崎慎司',
#  '金',
#  '表明',
#  'プロ野球',
#  'dynamite',
#  'ワケ',
#  '行為',
#  '相方',
#  'インターネット上',
#  '和田アキ子',
#  '足',
#  'お母さん',
#  '自身',
#  '可哀想',
#  '東京',
#  'ブーム',
#  '石川遼',
#  '最悪',
#  '最近',
#  '笑い',
#  'テレビ東京',
#  '怒り',
#  '昨年7月',
#  '仙台',
#  '交渉',
#  '得点',
#  '吸収',
#  '宮市',
#  '開幕投手',
#  'トップ',
#  '相手方',
#  '競技',
#  'フォアボール',
#  '浮上',
#  '斎藤',
#  'ブーイング',
#  'ピンチ',
#  '者',
#  'w杯最終予選',
#  '子供',
#  '変更',
#  '文句',
#  'inac神戸',
#  'ロシア',
#  'みたい',
#  '全力',
#  '時代',
#  '世間',
#  '運動量',
#  'スイッチ',
#  '酷評',
#  '就任',
#  '壁',
#  'スペース',
#  '抗議',
#  '中学校',
#  '程度',
#  '名',
#  '野球選手',
#  '担当',
#  '思い',
#  '丸山桂里奈',
#  'かなり',
#  'gm',
#  'レスラー',
#  '得意',
#  '左サイド',
#  '余裕',
#  '興奮',
#  '過酷',
#  'ロッテ',
#  'ギャグ',
#  '長友佑都',
#  '閉幕',
#  '失礼',
#  '今月2日',
#  '静か',
#  'ネット上',
#  '視線',
#  '韓国戦',
#  '度',
#  'ローテーション',
#  '彼女たち',
#  'サイド',
#  'ロンドン',
#  '国内組',
#  '必死',
#  '本音',
#  '興味',
#  '気持ち',
#  '節',
#  '迷い',
#  'レギュラー',
#  '秘密',
#  'メンバー',
#  '表情',
#  '動作',
#  '中日',
#  'ところ',
#  'you',
#  '一つ',
#  '返信',
#  '懸念',
#  'クロス',
#  '最下位',
#  '様',
#  'ラモス',
#  '美女',
#  'メキシコ',
#  '満足',
#  '上田',
#  'コメント欄',
#  '交流戦',
#  '開幕前',
#  '恋愛',
#  '残念',
#  '松井秀喜',
#  '先発',
#  '伝説',
#  '仕事',
#  'ポイント',
#  '発展',
#  '部分',
#  'ボール',
#  '香川真司',
#  '同誌',
#  '見事',
#  'フィギュアスケート',
#  '魔裟斗',
#  '言い方',
#  '視聴者',
#  '公式ブログ',
#  '阪神',
#  'オープン戦',
#  '丸山',
#  '立役者',
#  '一角',
#  '内田',
#  '嫁',
#  '熱戦',
#  '躍進',
#  'その後',
#  '技術',
#  '金メダリスト',
#  '李',
#  '悲願',
#  '女子サッカー界',
#  '失敗',
#  '出場機会',
#  '上',
#  '印象',
#  '崩壊',
#  '団体',
#  '車',
#  '独特',
#  '説明',
#  'スポット',
#  'なでしこジャパンメンバー',
#  'バッシング',
#  '在籍',
#  'コメント',
#  '夫',
#  '姿勢',
#  'シーン',
#  'ネタ',
#  '質問',
#  '新た',
#  '宮崎',
#  '地元',
#  '露骨',
#  '参加',
#  'サイン',
#  '力',
#  'オランダ',
#  'キャプテン',
#  '間違い',
#  '激怒',
#  'フリーアナウンサー',
#  'サプライズ',
#  '特別',
#  '球',
#  '写真',
#  '影',
#  'mlb',
#  'リズム',
#  '松井',
#  '代表',
#  '考え方',
#  'fw',
#  'サンデー・ジャポン',
#  'テレビ局',
#  '原因',
#  'ほう',
#  'いま',
#  'ストレート',
#  '闘莉王',
#  '支え',
#  'わけ',
#  '星野監督',
#  'プライベート',
#  '翌年',
#  '該当',
#  '普通',
#  'マスコミ',
#  '武田修宏',
#  '帰国後',
#  'レベルアップ',
#  '意欲',
#  'ホテル',
#  '澤',
#  '見出し',
#  'ヘディングシュート',
#  '北島康介',
#  'ハプニング',
#  '実力',
#  '苦言',
#  '試合',
#  '新人',
#  '友達',
#  '結末',
#  'モデル',
#  '字',
#  '実感',
#  '絶対',
#  '代表選手',
#  '才能',
#  '発生',
#  'ホームラン',
#  '矢先',
#  '若手',
#  'アウト',
#  '不安',
#  '複数',
#  '中学時代',
#  'みの',
#  'イタリア',
#  '好意的',
#  '北京五輪時',
#  '自信',
#  '加入',
#  '会社',
#  '週刊アサヒ芸能',
#  '企画',
#  '謝罪',
#  '途中交代',
#  '胸中',
#  'システム',
#  'レベル',
#  '絶対的',
#  '能力',
#  '矢部',
#  'スポーツ',
#  '年齢',
#  '中継',
#  '巨人軍',
#  '緊張',
#  '理解',
#  '松坂大輔',
#  '日本サッカー界',
#  '特徴',
#  '楽',
#  '突破',
#  '更新',
#  'フリップ',
#  '更',
#  '真央',
#  '桑田氏',
#  '印象的',
#  '日本ハム',
#  'あと',
#  'ステップ',
#  '遠藤',
#  '菅野',
#  '大学',
#  '茶の間',
#  'ドラフト会議',
#  '正直',
#  '五輪予選',
#  '趣味',
#  '日本代表メンバー',
#  '物議',
#  'エピソード',
#  '佐々木監督',
#  '当時',
#  'テレビ',
#  'ペルー代表',
#  'バランス',
#  '亀田興毅',
#  'うち',
#  '選出',
#  '岡ちゃん',
#  '大相撲',
#  '松井稼頭央',
#  '問い',
#  '方',
#  'アシスト',
#  '体',
#  '協力',
#  '浦和',
#  '中村俊輔',
#  'お父さん',
#  '先輩',
#  '中止',
#  '体操',
#  '上々',
#  '北澤豪氏',
#  'ビックリ',
#  '......」',
#  '一塁',
#  'アッコ',
#  'スレッド',
#  '明確',
#  'ジャッジ',
#  '仲田',
#  '記者',
#  '秋山',
#  '協会',
#  'ニューヒロイン',
#  '次世代',
#  '目',
#  '判定',
#  '公式サイト',
#  '今後',
#  '状態',
#  'ドイツ戦',
#  'ファイトマネー',
#  '圧力',
#  '登場',
#  '検査',
#  'リード',
#  '長谷部',
#  'ゲスト解説',
#  '松田',
#  '同氏',
#  '毎日',
#  '守護神',
#  '舞台',
#  '攻守',
#  '試合前',
#  'トリプルアクセル',
#  '世界選手権',
#  'バッティング',
#  '?”',
#  '今回',
#  '退団',
#  '可能',
#  'カメラマン',
#  '目的',
#  'レッドソックス',
#  '皆さん',
#  'チーム',
#  '変化球',
#  'チャンス',
#  '予選',
#  '和田毅',
#  '長野',
#  '子供達',
#  '健闘',
#  '歓喜',
#  'カッコ',
#  '近況',
#  '岡崎',
#  '吉田',
#  '相手',
#  '元',
#  '佐々木則夫監督',
#  '当初',
#  'ツイート',
#  '結成',
#  'バッター',
#  '勢い',
#  '古閑',
#  '山崎',
#  'センター',
#  '国内',
#  '流れ',
#  '盛り上がり',
#  '東北楽天',
#  '数字',
#  'ディフェンス',
#  'マウンド',
#  'mf',
#  '魅力',
#  'npb',
#  '音',
#  '金額',
#  '高橋',
#  'パフォーマンス',
#  '前',
#  '意気込み',
#  '切符',
#  'よう',
#  'オファー',
#  '事実',
#  '久しぶり',
#  '波紋',
#  '目玉',
#  '思い出',
#  '関係者',
#  '自分',
#  '事件',
#  '手',
#  '五輪',
#  'ライバル',
#  'ソフトバンクホークス',
#  '侮辱',
#  '北朝鮮',
#  '柔道',
#  'なでしこ',
#  'なでしこ達',
#  'キャスター',
#  '頭',
#  '結婚',
#  '事故',
#  '錦織圭',
#  '勝ち',
#  '汗',
#  '嘘',
#  '人生',
#  '逆転勝利',
#  '石川',
#  '開催中',
#  '通り',
#  '練習試合',
#  '強豪',
#  'ヤクルト',
#  '木村',
#  '実績',
#  '恩師',
#  '花',
#  'going',
#  '(笑)」',
#  '真剣',
#  '震災',
#  '岡田監督',
#  '時間',
#  'ユーザ',
#  '去年',
#  '評判',
#  '人事',
#  '予定',
#  'アスレチックス',
#  'お金',
#  'dena',
#  'クラブ',
#  'アメリカ',
#  '負け',
#  '異例',
#  '絶賛',
#  '東京ドーム',
#  '香川',
#  '的',
#  '対戦相手',
#  '腰',
#  '二人',
#  '佑ちゃん',
#  '辺',
#  '違和感',
#  '瞬間',
#  'キュート',
#  '奥さん',
#  '失点',
#  '経緯',
#  '指',
#  '背番号',
#  '代理人',
#  '父親',
#  '基本',
#  '彼女達',
#  '試合中',
#  'スタイル',
#  '招集',
#  '優勝',
#  'さまざま',
#  '選手',
#  'ミーティング',
#  '柔道家',
#  '王者',
#  '掲載',
#  'ロンドン五輪予選',
#  '真っ直ぐ',
#  'ケース',
#  '水',
#  '展開',
#  '意見',
#  '意識',
#  '舞',
#  '一人一人',
#  '受賞',
#  '本日',
#  'シーズン',
#  '大手掲示板',
#  '中国',
#  '本',
#  'きっかけ',
#  '肉体的',
#  'こいつ',
#  '意外',
#  '収録',
#  '現場',
#  '自分達',
#  '愛',
#  '低迷',
#  'なでしこジャパン',
#  '選手たち',
#  'ダルビッシュ',
#  '達成',
#  '放送',
#  'ザッケローニ監督',
#  '衝撃',
#  '守備',
#  '観客',
#  '直前',
#  '今年',
#  '簡単',
#  '嫌',
#  'テレビ朝日',
#  '表彰台',
#  'ママ',
#  '食事会',
#  'ショートプログラム',
#  'デスク',
#  'インパクト',
#  '落合博満氏',
#  'アメリカ戦',
#  '決意',
#  '石井',
#  'キム・ヨナ',
#  '照れ笑い',
#  'ペア',
#  'cm',
#  '負傷',
#  'イギリス',
#  '個人的',
#  '議論',
#  '自ら',
#  'おまかせ',
#  '解説',
#  '大会中',
#  'ピッチング',
#  'ため',
#  '際',
#  '通常',
#  '感情',
#  '理想',
#  'スタート',
#  'ロンドン五輪代表',
#  '金メダル獲得',
#  '幾つ',
#  '日本語',
#  '開催',
#  '調整',
#  '同点',
#  '浅田真央',
#  '打球',
#  'news23',
#  'ご飯',
#  '表現力',
#  '3-4-3',
#  '言い訳',
#  'オフィシャルブログ',
#  '準決勝',
#  '不調',
#  '全日本女子',
#  '対戦',
#  '浅尾',
#  '指導',
#  '——?',
#  '研究',
#  'ユニフォーム',
#  'スタジアム',
#  'サッカー界',
#  '本田圭佑',
#  '本田',
#  'シリーズ',
#  '重み',
#  'メダル',
#  'エース',
#  '子',
#  'ブログ上',
#  '可能性',
#  '危機',
#  '会',
#  'うえ',
#  '風',
#  '報道ステーション',
#  '安藤美姫',
#  '小学校',
#  '延長戦',
#  '体調',
#  '喜び',
#  '女王',
#  '独占インタビュー',
#  'たび',
#  '誕生日',
#  'フォロー',
#  '入団',
#  '証明',
#  'ロスタイム',
#  '真っ白',
#  'ヒット',
#  'ブラジル',
#  '経験',
#  '後半',
#  'w杯出場',
#  '完全',
#  '松岡修造',
#  '注目',
#  'ポーズ',
#  '近く',
#  'たくさん',
#  'コーナー',
#  '人材',
#  'パワー',
#  'カタチ',
#  '不満',
#  'カメルーン戦',
#  '擁護',
#  '日程',
#  'アテネ',
#  '指示',
#  '引退後',
#  'ツイッター上',
#  'エントリー',
#  '皆様',
#  '一本',
#  '両者',
#  '興毅',
#  '噂',
#  '奮闘',
#  '韓国',
#  'まま',
#  '熊谷',
#  'とんでも',
#  '野村',
#  'リング',
#  'スター',
#  '広島',
#  'チームメイト',
#  'アピール',
#  '金メダル',
#  '本業',
#  'jリーグ',
#  'オリックス',
#  'パス',
#  '起用',
#  'スウェーデン',
#  'コミュニケーション',
#  '先生',
#  '出演者',
#  '文字',
#  '調査',
#  '声',
#  '見方',
#  '覚悟',
#  'コントロール',
#  '連続',
#  '感じ',
#  'ドイツ',
#  '右',
#  '場',
#  'スポーツライター',
#  '冗談',
#  '付き合い',
#  '物',
#  '李忠成',
#  'とき',
#  'もん',
#  '怒り心頭',
#  'フジテレビ',
#  'さん',
#  '無理',
#  'ロンドン五輪',
#  '市川',
#  '全体',
#  ...]

# %%
cv = CV(analyzer=my_analyzer, min_df=0.005, max_df=0.6, vocabulary=tv_vocab2)
matrix_cv = cv.fit_transform(documents)
matrix_cv
# Out:
# <900x1569 sparse matrix of type '<class 'numpy.int64'>'
# 	with 28483 stored elements in Compressed Sparse Row format>

# %%
# sklearn の Multinomial Naive Bayes をインポート
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(matrix_cv, labels)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
clf.predict(matrix_cv)
# Out:
# array([ 0,  1,  2,  2,  2,  2,  3,  4,  1,  3,  3,  3,  3,  4,  5,  1,  3,
#         6,  4,  0,  1,  7,  1,  6,  8,  4,  4,  4,  1,  2,  9,  3,  9,  8,
#        10,  4, 11, 11,  6,  4,  7,  4,  3,  9, 10,  3,  4,  6,  9,  4,  4,
#        11,  4,  3,  6,  8,  6,  5,  6,  5, 11, 10,  8,  6,  5,  4,  6, 11,
#        11,  1,  6,  7, 11,  4,  6,  5,  6,  6,  6,  4,  8,  6,  6,  6,  6,
#         6,  4,  6,  6,  6,  6,  6,  6,  5,  6,  6,  6,  6,  6,  6,  6,  6,
#         6,  6,  6,  6,  6, 10,  6,  6, 10, 10,  7,  6,  4,  6,  6,  6,  4,
#         9,  2,  4,  9,  4,  0,  6,  6,  4,  4,  8,  4,  2,  6,  4,  4,  4,
#         9, 12,  6,  6,  6,  6,  5, 13,  5,  5,  6,  4,  5,  5,  4, 13,  4,
#         0,  0,  9,  6,  4,  6,  4,  3,  4,  9,  9, 11,  7, 14,  4,  4,  6,
#         7,  8,  7,  8,  4,  4,  4,  4,  6,  6,  6,  4,  6,  0,  6,  4,  4,
#         9,  4,  6,  9,  4,  4,  5,  7,  4,  4,  4,  4,  4,  0,  4,  8,  1,
#         4,  4,  4,  6,  6,  4,  3,  1,  4,  4,  7,  4,  4,  7,  4,  5,  9,
#         4,  4,  4,  4,  3,  4,  4,  8,  4,  5,  7,  4,  6,  4,  4,  4,  4,
#         4,  4,  6,  4,  7,  7,  6,  6,  4,  4,  4,  6,  4,  6,  6,  4,  6,
#         4,  4,  4,  7,  6, 11,  6,  4,  6,  6,  6,  6,  6,  9,  6, 10,  4,
#         4,  8, 10,  4,  4, 14,  6,  6,  4,  6, 14, 10, 11,  4,  4,  4,  4,
#         4,  4,  6,  4,  4,  4,  4,  1,  2,  4,  6, 11,  9, 11, 15,  4,  4,
#         8,  4,  3,  4,  7, 16,  4,  6, 12,  4,  6,  6, 15,  7, 11,  4,  4,
#         6,  6,  4,  6,  6, 19,  5,  5,  9,  3, 19,  4,  6,  2,  6,  6,  6,
#         2,  6,  5,  6,  6, 16,  4, 11, 15,  6,  6,  6,  4,  6,  4,  6,  6,
#         4,  3, 16, 11,  9, 13,  6,  6,  6,  6,  6,  2,  0, 16, 16,  6, 11,
#         6,  4,  2, 13,  6, 11,  6, 11, 11,  2, 13,  0, 13,  2,  0,  0, 13,
#         0, 13, 18,  0,  0, 12, 13, 18,  2, 13,  6,  0, 18, 17,  0, 16,  6,
#        12, 11,  6,  6, 11,  0, 17,  5,  6,  6,  4,  8,  6,  6,  4,  6])

# %%
from sklearn.metrics import confusion_matrix
result = clf.predict(matrix_cv)
confusion_matrix(labels, result)
conf_matrix = confusion_matrix(labels, result)
for i in range(len(label_list)):
    # クラス i に対する正解率の計算
    print(label_list[i] + ': ' + str(conf_matrix[i][i]) + '/' + str(sum(conf_matrix[i])))
    
    # 間違い先のクラス j を確認して，その件数を表示
    for j in range(len(label_list)):
        if j != i and conf_matrix[i][j] > 0:
            print("  " + label_list[j] + ': ' + str(conf_matrix[i][j]))

# 全体の正解率（accuracy）の計算
#  全体の正解数＝対角成分の総和：sum(conf_matrix.diagonal())
#  事例の総数：len(labels)
#  round()関数は値を丸めるため
print('accuracy = ' + str(round(sum(conf_matrix.diagonal()) / len(labels), 4)))
# Out:
# 柔道: 18/19
#   総合格闘技: 1
# 競馬: 12/12
# その他: 26/26
# フィギュアスケート: 31/32
#   プロレス: 1
# 野球: 258/264
#   その他: 1
#   サッカー: 4
#   ボクシング: 1
# プロレス: 18/18
# サッカー: 325/333
#   野球: 1
#   総合格闘技: 1
#   ゴルフ: 1
#   ボクシング: 1
#   総合: 2
#   陸上: 2
# 総合格闘技: 25/26
#   野球: 1
# ゴルフ: 22/22
# ボクシング: 24/24
# 相撲: 10/11
#   サッカー: 1
# 総合: 31/32
#   体操: 1
# バドミントン: 7/7
# 水泳: 18/18
# ビーチバレー: 6/6
# テニス: 12/12
# 陸上: 17/17
# レスリング: 6/6
# 体操: 7/8
#   フィギュアスケート: 1
# バレーボール: 7/7
# accuracy = 0.9778

# %%
from sklearn.model_selection import cross_val_score

# %%
scores=cross_val_score(clf,matrix_cv,labels)

# %%
scores
# Out:
# array([0.70491803, 0.71096346, 0.76870748])

# %% [markdown]
# 知らない文書だと３割くらい間違える

# %%
print('Cross\Validation scores:{}'.format(scores))
import numpy as np
print('Average score: {}'.format(np.mean(scores)))
# Out:
# Cross\Validation scores:[0.70491803 0.71096346 0.76870748]
# Average score: 0.7281963236431949

# %%
scores=cross_val_score(clf,matrix_cv,labels,cv=5)

# %%
print('Cross\Validation scores:{}'.format(scores))
print('Average score: {}'.format(np.mean(scores)))
# Out:
# Cross\Validation scores:[0.69633508 0.69354839 0.75842697 0.77586207 0.71929825]
# Average score: 0.7286941493004986

# %% [markdown]
# 5分割した。五つに差があり、学習のバランスが悪い！
# （記事に出てきやすいスポーツがあるので）
# 乱数を変えて何度かやってみると良い。

# %%
scores=cross_val_score(clf,matrix_cv,labels,cv=10)
print('Cross\Validation scores:{}'.format(scores))
print('Average score: {}'.format(np.mean(scores)))
# Out:
# Cross\Validation scores:[0.71       0.70707071 0.72340426 0.69892473 0.76923077 0.7032967
#  0.77011494 0.79761905 0.81481481 0.7375    ]
# Average score: 0.7431975971062722
# C:\Users\yuimaeka\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:605: Warning: The least populated class in y has only 6 members, which is too few. The minimum number of members in any class cannot be less than n_splits=10.
#   % (min_groups, self.n_splits)), Warning)

# %% [markdown]
# 10だと怒られる。The least populated class in y has only 6 members　で、一番少ないグループは6記事しか入らないので、学習が上手くいかない事の警告。
# 「層状サンプリング」ランダムでやるとクラスの分布がぐちゃぐちゃになるので、
# 各クラスからクラスと同じ割合で選ばれるようにすること。
# 数値の平均をどれだけ挙げられるかが鍵。

# %%
clf.fit(matrix_cv,labels)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# HTMLに出力する。

# %%
result=clf.predict(matrix_cv)
c_i_list=[(c,i)for i,c in enumerate(result)]
c_i_list_sorted=sorted(c_i_list)

# %%
c_i_list_sorted
# Out:
# [(0, 0),
#  (0, 19),
#  (0, 124),
#  (0, 153),
#  (0, 154),
#  (0, 183),
#  (0, 200),
#  (0, 787),
#  (0, 845),
#  (0, 861),
#  (0, 864),
#  (0, 865),
#  (0, 867),
#  (0, 870),
#  (0, 871),
#  (0, 878),
#  (0, 881),
#  (0, 889),
#  (1, 1),
#  (1, 8),
#  (1, 15),
#  (1, 20),
#  (1, 22),
#  (1, 28),
#  (1, 69),
#  (1, 203),
#  (1, 211),
#  (1, 296),
#  (1, 529),
#  (1, 597),
#  (2, 2),
#  (2, 3),
#  (2, 4),
#  (2, 5),
#  (2, 29),
#  (2, 120),
#  (2, 131),
#  (2, 297),
#  (2, 325),
#  (2, 333),
#  (2, 352),
#  (2, 389),
#  (2, 468),
#  (2, 479),
#  (2, 491),
#  (2, 495),
#  (2, 627),
#  (2, 766),
#  (2, 786),
#  (2, 791),
#  (2, 812),
#  (2, 816),
#  (2, 844),
#  (2, 852),
#  (2, 859),
#  (2, 863),
#  (2, 875),
#  (3, 6),
#  (3, 9),
#  (3, 10),
#  (3, 11),
#  (3, 12),
#  (3, 16),
#  (3, 31),
#  (3, 42),
#  (3, 45),
#  (3, 53),
#  (3, 160),
#  (3, 210),
#  (3, 225),
#  (3, 308),
#  (3, 338),
#  (3, 339),
#  (3, 342),
#  (3, 344),
#  (3, 347),
#  (3, 361),
#  (3, 399),
#  (3, 410),
#  (3, 470),
#  (3, 510),
#  (3, 523),
#  (3, 559),
#  (3, 560),
#  (3, 591),
#  (3, 671),
#  (3, 764),
#  (3, 808),
#  (3, 834),
#  (4, 7),
#  (4, 13),
#  (4, 18),
#  (4, 25),
#  (4, 26),
#  (4, 27),
#  (4, 35),
#  (4, 39),
#  (4, 41),
#  (4, 46),
#  (4, 49),
#  (4, 50),
#  (4, 52),
#  (4, 65),
#  (4, 73),
#  (4, 79),
#  (4, 86),
#  (4, 114),
#  (4, 118),
#  (4, 121),
#  (4, 123),
#  (4, 127),
#  (4, 128),
#  (4, 130),
#  (4, 133),
#  (4, 134),
#  (4, 135),
#  (4, 147),
#  (4, 150),
