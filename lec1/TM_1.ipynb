# %% [markdown]
# # 1.janome の使い方
# ***

# %% [markdown]
# janomeを用いて日本語の文字列を形態素解析する。
#
# ## 1.1 janomeの基本
#
# TokenizerをインポートしてTokenizerオブジェクトのインスタンスを生成、tokenize()メソッドに対象の文字列を渡す。tokenize()メソッドはjanome.tokenizer.Tokenオブジェクトを要素とするリストを返す。

# %%
#janomeのインポート
from janome.tokenizer import Tokenizer
t=Tokenizer()

# %%
#試しに文字列を形態素解析してみる
print(t.tokenize('すもももももももものうち')[0])
# Out:
# すもも	名詞,一般,*,*,*,*,すもも,スモモ,スモモ

# %%
for token in t.tokenize('すもももももももものうち'):
    print(token)
# Out:
# すもも	名詞,一般,*,*,*,*,すもも,スモモ,スモモ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# うち	名詞,非自立,副詞可能,*,*,*,うち,ウチ,ウチ

# %%
for token in t.tokenize('きっと彼女も喜んでくれると思います'):
    print(token)
# Out:
# きっと	副詞,一般,*,*,*,*,きっと,キット,キット
# 彼女	名詞,代名詞,一般,*,*,*,彼女,カノジョ,カノジョ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# 喜ん	動詞,自立,*,*,五段・バ行,連用タ接続,喜ぶ,ヨロコン,ヨロコン
# で	助詞,接続助詞,*,*,*,*,で,デ,デ
# くれる	動詞,非自立,*,*,一段・クレル,基本形,くれる,クレル,クレル
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# 思い	動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ
# ます	助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス

# %% [markdown]
# 試しに動詞を含む文章でやってみた。
# 動詞の場合、活用の種類等もデータとして返ってくる事がわかる。
#
# ***
# ## 1.2 名詞だけ抜き取る

# %%
#データ型の確認
tt=t.tokenize('すもももももももものうち')
type(tt)
# Out:
# list

# %%
#データ型の確認
type(tt[0])
# Out:
# janome.tokenizer.Token

# %%
#中身を見てみる
vars(tt[0])
# Out:
# {'surface': 'すもも',
#  'part_of_speech': '名詞,一般,*,*',
#  'infl_type': '*',
#  'infl_form': '*',
#  'base_form': 'すもも',
#  'reading': 'スモモ',
#  'phonetic': 'スモモ',
#  'node_type': 'SYS_DICT'}

# %%
tt[0].base_form
# Out:
# 'すもも'

# %%
for token in t.tokenize('すもももももももものうち'):
    if token.part_of_speech.split(',')[0]=='名詞':
        print(token)
# Out:
# すもも	名詞,一般,*,*,*,*,すもも,スモモ,スモモ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# うち	名詞,非自立,副詞可能,*,*,*,うち,ウチ,ウチ

# %% [markdown]
# token内のデータ型を確認し、名詞のみを抜き出す事ができた。
# part_of_speechに単語情報が文字列として入っているので、これをカンマ区切りにし
# 最初の要素を見ることで名詞かどうかを判定している。
# 単語自体を見たいばあいはbase_formを用いる。

# %%
#リスト内包表記
tt=[token.base_form for token in t.tokenize('すもももももももものうち') if token.part_of_speech.split(',')[0]=='名詞']

# %%
#構造化されていたらこっち
for token in tt:
    print(token)
# Out:
# すもも
# もも
# もも
# うち

# %%
tt
# Out:
# ['すもも', 'もも', 'もも', 'うち']

# %% [markdown]
# ***
#
# ## 1.3 単語のカウント
# 以下２種類の方法で単語のカウントができる。
# Python標準ライブラリcollectionsのCounterクラスはリスト内の単語を自動でカウントし、出現回数の多い順に要素を取得できる。
# defaultdictはキーがなかった際に自動で初期値0（intの場合）で要素を作ってくれる辞書型である。　[参考](https://qiita.com/xza/items/72a1b07fcf64d1f4bdb7)

# %%
from collections import Counter
tc=Counter(tt)
print(tc)
# Out:
# Counter({'もも': 2, 'すもも': 1, 'うち': 1})

# %%
from collections import defaultdict
d=defaultdict(int)
for ttt in tt:
    d[ttt]+=1
print(d)
# Out:
# defaultdict(<class 'int'>, {'すもも': 1, 'もも': 2, 'うち': 1})

# %%
#分かち書きだしたければ、　wakati=True を指定する
for token in t.tokenize('すもももももももものうち',wakati=True):
    print(token)
# Out:
# すもも
# も
# もも
# も
# もも
# の
# うち

# %% [markdown]
# ***
# ## 1.4 ファイルからの入力
#
# ファイルから入力したい時、codecsを使う。
# codecsは文字コードを気にするファイル入力である。
# fはファイルポインタのように用いる事ができ、
# ファイルをクローズしなくていいというメリットがある。

# %%
import codecs
with codecs.open('input.txt','r','utf8') as f:
    text=f.read()
    for token in t.tokenize(text,stream=True):
        print(token)
# Out:
# Stardew	名詞,固有名詞,組織,*,*,*,Stardew,*,*
#  	記号,空白,*,*,*,*, ,*,*
# Valley	名詞,固有名詞,組織,*,*,*,Valley,*,*
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# ，	記号,読点,*,*,*,*,，,，,，
# 農地	名詞,一般,*,*,*,*,農地,ノウチ,ノーチ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 開拓	名詞,サ変接続,*,*,*,*,開拓,カイタク,カイタク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# さまざま	名詞,形容動詞語幹,*,*,*,*,さまざま,サマザマ,サマザマ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# 作物	名詞,一般,*,*,*,*,作物,サクモツ,サクモツ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 栽培	名詞,サ変接続,*,*,*,*,栽培,サイバイ,サイバイ
# ，	記号,読点,*,*,*,*,，,，,，
# 収穫	名詞,サ変接続,*,*,*,*,収穫,シュウカク,シューカク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# ，	記号,読点,*,*,*,*,，,，,，
# 動物	名詞,一般,*,*,*,*,動物,ドウブツ,ドーブツ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 飼育	名詞,サ変接続,*,*,*,*,飼育,シイク,シイク
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# ，	記号,読点,*,*,*,*,，,，,，
# 鉱山	名詞,一般,*,*,*,*,鉱山,コウザン,コーザン
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 探検	名詞,サ変接続,*,*,*,*,探検,タンケン,タンケン
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# たり	助詞,並立助詞,*,*,*,*,たり,タリ,タリ
# と	助詞,格助詞,引用,*,*,*,と,ト,ト
# ，	記号,読点,*,*,*,*,，,，,，
# さまざま	名詞,形容動詞語幹,*,*,*,*,さまざま,サマザマ,サマザマ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# コンテンツ	名詞,一般,*,*,*,*,コンテンツ,コンテンツ,コンテンツ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 楽しめる	動詞,自立,*,*,一段,基本形,楽しめる,タノシメル,タノシメル
# 農場	名詞,一般,*,*,*,*,農場,ノウジョウ,ノージョー
# 経営	名詞,サ変接続,*,*,*,*,経営,ケイエイ,ケイエイ
# シミュレーション	名詞,サ変接続,*,*,*,*,シミュレーション,シミュレーション,シミュレーション
# ゲーム	名詞,一般,*,*,*,*,ゲーム,ゲーム,ゲーム
# だ	助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ
# 。	記号,句点,*,*,*,*,。,。,。
# ,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# ,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 　	記号,空白,*,*,*,*,　,　,
# 今回	名詞,副詞可能,*,*,*,*,今回,コンカイ,コンカイ
# リリース	名詞,サ変接続,*,*,*,*,リリース,リリース,リリース
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れ	動詞,接尾,*,*,一段,連用形,れる,レ,レ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# iOS	名詞,一般,*,*,*,*,iOS,*,*
# 版	名詞,接尾,一般,*,*,*,版,バン,バン
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# ，	記号,読点,*,*,*,*,，,，,，
# 10	名詞,数,*,*,*,*,10,*,*
# 月	名詞,一般,*,*,*,*,月,ツキ,ツキ
# 9	名詞,数,*,*,*,*,9,*,*
# 日	名詞,接尾,助数詞,*,*,*,日,ニチ,ニチ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 掲載	名詞,サ変接続,*,*,*,*,掲載,ケイサイ,ケイサイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# 記事	名詞,一般,*,*,*,*,記事,キジ,キジ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# お伝え	名詞,サ変接続,*,*,*,*,お伝え,オツタエ,オツタエ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# とおり	名詞,非自立,副詞可能,*,*,*,とおり,トオリ,トーリ
# ，	記号,読点,*,*,*,*,，,，,，
# バージョン	名詞,一般,*,*,*,*,バージョン,バージョン,バージョン
# 1	名詞,数,*,*,*,*,1,*,*
# .	名詞,サ変接続,*,*,*,*,.,*,*
# 3	名詞,数,*,*,*,*,3,*,*
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# シングルプレイコンテンツ	名詞,一般,*,*,*,*,シングルプレイコンテンツ,*,*
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 収録	名詞,サ変接続,*,*,*,*,収録,シュウロク,シューロク
# さ	動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ
# れる	動詞,接尾,*,*,一段,基本形,れる,レル,レル
# 。	記号,句点,*,*,*,*,。,。,。
# ,*,*
#
# 	記号,空白,*,*,*,*,
# ,*,*
# 　	記号,空白,*,*,*,*,　,　,
# また	接続詞,*,*,*,*,*,また,マタ,マタ
# ，	記号,読点,*,*,*,*,，,，,，
# タッチスクリーン	名詞,一般,*,*,*,*,タッチスクリーン,*,*
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# 操作	名詞,サ変接続,*,*,*,*,操作,ソウサ,ソーサ
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 合わせ	動詞,自立,*,*,一段,連用形,合わせる,アワセ,アワセ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# ，	記号,読点,*,*,*,*,，,，,，
# 新た	名詞,形容動詞語幹,*,*,*,*,新た,アラタ,アラタ
# な	助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ
# ユーザー	名詞,一般,*,*,*,*,ユーザー,ユーザー,ユーザー
# インタフェース	名詞,一般,*,*,*,*,インタフェース,インタフェース,インタフェース
# と	助詞,並立助詞,*,*,*,*,と,ト,ト
# メニュー	名詞,一般,*,*,*,*,メニュー,メニュー,メニュー
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# 用意	名詞,サ変接続,*,*,*,*,用意,ヨウイ,ヨーイ
# し	動詞,自立,*,*,サ変・スル,連用形,する,シ,シ
# た	助動詞,*,*,*,特殊・タ,基本形,た,タ,タ
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# や	助詞,並立助詞,*,*,*,*,や,ヤ,ヤ
# ，	記号,読点,*,*,*,*,，,，,，
# PC	名詞,一般,*,*,*,*,PC,*,*
# 版	名詞,接尾,一般,*,*,*,版,バン,バン
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# プレイヤー	名詞,一般,*,*,*,*,プレイヤー,プレイヤー,プレイヤー
# は	助詞,係助詞,*,*,*,*,は,ハ,ワ
# ，	記号,読点,*,*,*,*,，,，,，
# セーブ	名詞,サ変接続,*,*,*,*,セーブ,セーブ,セーブ
# データ	名詞,一般,*,*,*,*,データ,データ,データ
# を	助詞,格助詞,一般,*,*,*,を,ヲ,ヲ
# iTunes	名詞,固有名詞,組織,*,*,*,iTunes,*,*
# 経由	名詞,サ変接続,*,*,*,*,経由,ケイユ,ケイユ
# で	助詞,格助詞,一般,*,*,*,で,デ,デ
# iOS	名詞,一般,*,*,*,*,iOS,*,*
# 版	名詞,接尾,一般,*,*,*,版,バン,バン
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 転送	名詞,サ変接続,*,*,*,*,転送,テンソウ,テンソー
# できる	動詞,自立,*,*,一段,基本形,できる,デキル,デキル
# こと	名詞,非自立,一般,*,*,*,こと,コト,コト
# が	助詞,格助詞,一般,*,*,*,が,ガ,ガ
# 特徴	名詞,一般,*,*,*,*,特徴,トクチョウ,トクチョー
# に	助詞,格助詞,一般,*,*,*,に,ニ,ニ
# 挙げ	動詞,自立,*,*,一段,未然形,挙げる,アゲ,アゲ
# られ	動詞,接尾,*,*,一段,連用形,られる,ラレ,ラレ
# て	助詞,接続助詞,*,*,*,*,て,テ,テ
# いる	動詞,非自立,*,*,一段,基本形,いる,イル,イル
# 。	記号,句点,*,*,*,*,。,。,。

# %% [markdown]
# ツイート1000件で試してみた。（一度データが大きすぎて怒られた　[参考](https://qiita.com/inoue0426/items/071c127428112f498421)）

# %%
import codecs
with codecs.open('tweet.txt','r','utf8') as f:
    text=f.read()
    twe=[token.base_form for token in t.tokenize(text,stream=True) if token.part_of_speech.split(',')[0]=='名詞']
    twec=Counter(twe)
    print(twec)
# Out:
# Counter({'/': 9612, '.': 9360, 't': 9108, 'https': 9047, '://': 8952, 'co': 8849, '_': 8542, '@': 7956, 'RT': 7855, ':': 7459, '#': 5354, '1': 2460, '2': 2192, '3': 1838, '4': 1627, '7': 1545, '0': 1505, '9': 1439, '5': 1423, '6': 1347, '8': 1310, '10': 1244, '日': 1162, 'さん': 1054, '(': 969, ')': 881, '人': 792, 'の': 712, '✨': 665, 'フォロー': 614, 'ん': 603, '中': 555, '月': 538, 'これ': 487, 'ちゃん': 474, '様': 468, '名': 458, 'ー': 449, 'こと': 447, 'プレゼント': 430, '今日': 424, '方': 417, '参加': 376, '～': 365, '目': 363, '17': 341, '__': 313, '一': 311, '-': 311, '今': 306, '円': 303, '時': 301, '者': 299, 'キャンペーン': 297, '抽選': 294, ';': 293, '11': 290, '好き': 288, '開催': 287, '&': 285, '20': 276, '私': 275, '年': 270, '画像': 258, '前': 254, '動画': 252, '何': 251, '発売': 248, '結果': 248, '2018': 247, '♪': 245, 'A': 242, 'm': 236, '23': 229, '写真': 229, 's': 229, 'a': 228, '30': 226, '19': 226, 'お願い': 224, 'ツイート': 224, '18': 223, '応募': 221, '12': 216, '明日': 216, 'よう': 215, '回': 214, 'amp': 212, 'w': 211, 'o': 210, '00': 207, '笑': 206, '登場': 205, '募集': 204, '万': 203, 'リツイート': 200, '毎日': 197, '本日': 195, 'S': 193, '59': 192, '100': 192, 'くん': 191, '女子': 187, 'こちら': 186, 'k': 184, '分': 184, '記念': 184, 'D': 182, 'C': 181, '⇒': 180, 'h': 178, 'R': 177, 'さ': 176, '投稿': 176, '‼': 176, '_:': 172, 'F': 171, '猫': 169, 'そう': 166, '話': 166, 'B': 163, '事': 162, 'i': 162, '21': 162, '❗': 159, ',': 159, '公開': 158, 'イベント': 156, '日本': 155, 'M': 152, 'd': 151, '限定': 151, '❤': 150, '１': 150, 'n': 150, 'T': 149, 'x': 148, '情報': 148, '自分': 147, '企画': 145, 'y': 143, '15': 143, 'J': 143, '公式': 143, 'c': 143, '22': 142, '参戦': 141, 'みんな': 140, 'E': 139, 'P': 138, 'L': 136, '\u3000#': 135, '時間': 134, 'u': 134, 'ID': 133, '無料': 132, 'Y': 131, '本': 131, 'Lv': 131, '気': 130, '的': 130, 'もの': 128, 'お知らせ': 128, 'G': 127, '24': 126, '13': 126, 'b': 126, 'H': 125, 'クーポン': 125, 'N': 125, '希望': 125, 'r': 125, '女の子': 124, 'e': 123, '!': 123, 'U': 123, '期間': 122, 'I': 122, 'g': 122, '後': 122, '枚': 122, '詳細': 122, '子': 120, '拡散': 120, 'Twitter': 120, 'アカウント': 120,